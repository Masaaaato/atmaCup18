# %%
# !pip install -q dask[dataframe]
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.2/243.2 kB 11.7 MB/s eta 0:00:00

# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
import glob
from argparse import Namespace
from joblib import Parallel, delayed

from tqdm import tqdm
import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold, StratifiedGroupKFold
import xgboost as xgb
from xgboost import XGBRegressor

print("xgboost version:", xgb.__version__)
# Out:
# xgboost version: 2.1.2

# %%
config = dict(
    exp = "xx",
    input_dir = "xxxxx",
    output_dir = "xxxx",
    image_dir = "xxxx",
    n_folds = 5,
    seed = 0,
    learning_rate = 0.003,
    max_depth = 11,
    min_child_weight = 9,
    gamma = 0.15,
    reg_alpha = 3.25,
    reg_lambda = 1.38,
    subsample = 0.8,
    colsample_bytree = 0.265,
)
config = Namespace(**config)

# %%
####################
### Load Data
####################
train_df = pd.read_csv(os.path.join(config.output_dir, "train_features_w_cluster.csv"))
train_df["scene_id"] = train_df["ID"].apply(lambda x: x.split("_")[0])
train_df["frame_id"] = train_df["ID"].apply(lambda x: x.split("_")[1]).astype("int")
train_df = train_df.sort_values(["scene_id", "frame_id"], ascending=True).reset_index(drop=True)
train_scene_id2num = train_df["scene_id"].value_counts().to_dict()
train_df.index = train_df.ID
display(train_df.head())
display(train_df.shape)

test_df = pd.read_csv(os.path.join(config.output_dir, "test_features_w_cluster.csv"))
test_df["scene_id"] = test_df["ID"].apply(lambda x: x.split("_")[0])
test_df["frame_id"] = test_df["ID"].apply(lambda x: x.split("_")[1]).astype("int")
test_df = test_df.sort_values(["scene_id", "frame_id"], ascending=True).reset_index(drop=True)
test_scene_id2num = test_df["scene_id"].value_counts().to_dict()
test_df.index = test_df.ID
display(test_df.head())
display(test_df.shape)
# Out:
#                                                                         ID  ...  frame_id
# ID                                                                          ...
# 00066be8e20318869c38c66be466631a_320  00066be8e20318869c38c66be466631a_320  ...       320
# 00066be8e20318869c38c66be466631a_420  00066be8e20318869c38c66be466631a_420  ...       420
# 00066be8e20318869c38c66be466631a_520  00066be8e20318869c38c66be466631a_520  ...       520
# 000fb056f97572d384bae4f5fc1e0f28_20    000fb056f97572d384bae4f5fc1e0f28_20  ...        20
# 000fb056f97572d384bae4f5fc1e0f28_120  000fb056f97572d384bae4f5fc1e0f28_120  ...       120
#
# [5 rows x 33 columns]
# (43371, 33)
#                                                                         ID  ...  frame_id
# ID                                                                          ...
# 012baccc145d400c896cb82065a93d42_120  012baccc145d400c896cb82065a93d42_120  ...       120
# 012baccc145d400c896cb82065a93d42_220  012baccc145d400c896cb82065a93d42_220  ...       220
# 012baccc145d400c896cb82065a93d42_320  012baccc145d400c896cb82065a93d42_320  ...       320
# 012baccc145d400c896cb82065a93d42_420  012baccc145d400c896cb82065a93d42_420  ...       420
# 01d738e799d260a10f6324f78023b38f_120  01d738e799d260a10f6324f78023b38f_120  ...       120
#
# [5 rows x 15 columns]
# (1727, 15)

# %%
cols = ["vEgo", "aEgo", "steeringAngleDeg", "steeringTorque", "gas"]

# 標準的な統計
train_stat_df = train_df.groupby("scene_id").agg({
    col: ["max", "min", "mean", "std"] for col in cols
}).reset_index()
train_stat_df.columns = ["_".join(col) if col != ("scene_id", "") else "scene_id" for col in train_stat_df.columns]

test_stat_df = test_df.groupby("scene_id").agg({
    col: ["max", "min", "mean", "std"] for col in cols
}).reset_index()
test_stat_df.columns = ["_".join(col) if col != ("scene_id", "") else "scene_id" for col in test_stat_df.columns]

# 時系列処理
shift_diff_train_df = train_df.groupby("scene_id").apply(
    lambda group: pd.DataFrame({
        **{f"{col}_shift1": group[col].shift(1) for col in cols},
        **{f"{col}_shift-1": group[col].shift(-1) for col in cols},
        **{f"{col}_diff1": group[col].diff(1) for col in cols},
        **{f"{col}_diff-1": group[col].diff(-1) for col in cols}
    })
).reset_index(level=1).reset_index(drop=True)

shift_diff_test_df = test_df.groupby("scene_id").apply(
    lambda group: pd.DataFrame({
        **{f"{col}_shift1": group[col].shift(1) for col in cols},
        **{f"{col}_shift-1": group[col].shift(-1) for col in cols},
        **{f"{col}_diff1": group[col].diff(1) for col in cols},
        **{f"{col}_diff-1": group[col].diff(-1) for col in cols}
    })
).reset_index(level=1).reset_index(drop=True)
# Out:
# <ipython-input-6-4d123ea7aa21>:15: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   shift_diff_train_df = train_df.groupby("scene_id").apply(
# <ipython-input-6-4d123ea7aa21>:24: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   shift_diff_test_df = test_df.groupby("scene_id").apply(

# %%
train_df = train_df.merge(train_stat_df, on="scene_id", how="left")
test_df = test_df.merge(test_stat_df, on="scene_id", how="left")

train_df = train_df.merge(shift_diff_train_df, on=["ID"], how="left")
test_df = test_df.merge(shift_diff_test_df, on=["ID"], how="left")

# %%
# 信号機情報
traffic_lights_df = pd.read_csv(os.path.join(config.input_dir, "traffic_lights_df.csv"))
id2cls = dict(zip(traffic_lights_df["ID"],traffic_lights_df["class"]))
display(traffic_lights_df["class"].value_counts())

# エンコード
encode_label = np.diag(np.ones(len(traffic_lights_df["class"].unique()) + 1)) # +1はnodetectedのため
class2onehot = {f"light_{cls}": encode_label[i] for i, cls in enumerate(traffic_lights_df["class"].unique())}
class2onehot["light_nodetected"] = encode_label[-1]

# onehot化
train_light_class = pd.DataFrame(
    np.stack(train_df["ID"].apply(lambda x: class2onehot[f"light_{id2cls[x]}"] if x in id2cls else class2onehot["light_nodetected"])).astype(int),
    columns=[f"light_{cls}" for cls in traffic_lights_df["class"].unique()] + ["light_nodetected"]
)
test_light_class = pd.DataFrame(
    np.stack(test_df["ID"].apply(lambda x: class2onehot[f"light_{id2cls[x]}"] if x in id2cls else class2onehot["light_nodetected"])).astype(int),
    columns=[f"light_{cls}" for cls in traffic_lights_df["class"].unique()] + ["light_nodetected"]
)
train_df = pd.concat([train_df, train_light_class], axis=1)
test_df = pd.concat([test_df, test_light_class], axis=1)
# Out:
# class
# green       5879
# red         4915
# empty       1352
# yellow       682
# straight     647
# left         576
# right        306
# other         60
# Name: count, dtype: int64

# %%
# gearShifterはdriveかparkのみ使用
train_df["gearDrive"] = (train_df["gearShifter"] == "drive").astype(int)
test_df["gearDrive"] = (test_df["gearShifter"] == "drive").astype(int)
train_df["gearPark"] = (train_df["gearShifter"] == "park").astype(int)
test_df["gearPark"] = (test_df["gearShifter"] == "park").astype(int)

train_df = train_df.drop(columns=["gearShifter"])
test_df = test_df.drop(columns=["gearShifter"])

# %%
# 画像情報
from sklearn.decomposition import TruncatedSVD

# IDの順番がわからなくなったので、IDだけ読み込む
train_ids = pd.read_csv(os.path.join(config.output_dir, "train_features_w_cluster.csv"))["ID"].values
test_ids = pd.read_csv(os.path.join(config.output_dir, "test_features_w_cluster.csv"))["ID"].values

# SVD
svd_dim = 10
train_image_feats = np.load(os.path.join(config.output_dir, f"train_DETR_backbone_feats_t.npy")) # N, 8, 2048
test_image_feats = np.load(os.path.join(config.output_dir, f"test_DETR_backbone_feats_t.npy"))
all_image_feats = np.concatenate([train_image_feats, test_image_feats], axis=0)

feat_svd_df = pd.concat([
    pd.DataFrame(TruncatedSVD(n_components=svd_dim, random_state=config.seed).fit_transform(all_image_feats[:, i, :]), columns=[f"SVD{i}_{j}" for j in range(svd_dim)])
    for i in range(all_image_feats.shape[1])
], axis=1)

train_feat_svd_df = feat_svd_df[:len(train_ids)].reset_index(drop=True)
test_feat_svd_df = feat_svd_df[len(train_ids):].reset_index(drop=True)

del feat_svd_df, train_image_feats, test_image_feats, all_image_feats

# %%
# 与えられる3点の画像の類似度
train_corrs_0_05 = np.load(os.path.join(config.output_dir, "train_DETR_backbone_feats_t_t-0.5_corrs.npy")) # 現時点と-0.5との類似度
train_corrs_05_1 = np.load(os.path.join(config.output_dir, "train_DETR_backbone_feats_t-0.5_t-1.0_corrs.npy")) # -0.5と-1.0との類似度

test_corrs_0_05 = np.load(os.path.join(config.output_dir, "test_DETR_backbone_feats_t_t-0.5_corrs.npy")) # 現時点と-0.5との類似度
test_corrs_05_1 = np.load(os.path.join(config.output_dir, "test_DETR_backbone_feats_t-0.5_t-1.0_corrs.npy")) # -0.5と-1.0との類似度

train_corrs_df = pd.DataFrame(np.concatenate([train_corrs_0_05, train_corrs_05_1], axis=1), columns=[f"corr_t_0_05_{i}" for i in range(8)]+[f"corr_t_05_1_{i}" for i in range(8)])
test_corrs_df = pd.DataFrame(np.concatenate([test_corrs_0_05, test_corrs_05_1], axis=1), columns=[f"corr_t_0_05_{i}" for i in range(8)]+[f"corr_t_05_1_{i}" for i in range(8)])

train_image_feat_df = pd.concat([train_feat_svd_df, train_corrs_df], axis=1)
train_image_feat_df["ID"] = train_ids
train_df = train_df.merge(train_image_feat_df, on="ID", how="left")

test_image_feat_df = pd.concat([test_feat_svd_df, test_corrs_df], axis=1)
test_image_feat_df["ID"] = test_ids
test_df = test_df.merge(test_image_feat_df, on="ID", how="left")

del train_feat_svd_df, train_corrs_df, test_feat_svd_df, test_corrs_df, train_image_feat_df, test_image_feat_df

# %%
# brakeカラムは全部0なので除外
train_df = train_df.drop(columns=["brake"])
test_df = test_df.drop(columns=["brake"])

# %%
# Load OOF
targets = ['x_0', 'y_0', 'z_0', 'x_1', 'y_1', 'z_1', 'x_2', 'y_2', 'z_2', 'x_3', 'y_3', 'z_3', 'x_4', 'y_4', 'z_4', 'x_5', 'y_5', 'z_5']
noise_std = [0.03, 0.015, 0.01, 0.05, 0.03, 0.02, 0.08, 0.04, 0.025, 0.1, 0.065, 0.035, 0.15, 0.09, 0.045, 0.2, 0.13, 0.05]

np.random.seed(config.seed)

## OOFのパスは適宜設定してください.

oof_df = pd.read_csv(os.path.join(config.output_dir, f"37_convnext_large", "oof_predictions.csv"))
# adding gausian noise
for i, target in enumerate(targets):
    oof_df.loc[:, target] += 0.5 * np.random.normal(0, noise_std[i], len(oof_df))
oof_df = oof_df.set_index("ID").loc[train_df["ID"].values].reset_index(drop=True)

test_preds_df = pd.read_csv(os.path.join(config.output_dir, f"37_convnext_large", "test_predictions.csv"))
# adding gausian noise
for i, target in enumerate(targets):
    test_preds_df.loc[:, target] += 0.5 * np.random.normal(0, noise_std[i], len(test_preds_df))
test_preds_df = test_preds_df.set_index("ID").loc[test_df["ID"].values].reset_index(drop=True)

columns = [f"convnext_large_v37_{col}" for col in oof_df.columns]
oof_df.columns = columns
test_preds_df.columns = columns

train_df = pd.concat([train_df, oof_df], axis=1)
test_df = pd.concat([test_df, test_preds_df], axis=1)

# %%
# Load OOF
targets = ['x_0', 'y_0', 'z_0', 'x_1', 'y_1', 'z_1', 'x_2', 'y_2', 'z_2', 'x_3', 'y_3', 'z_3', 'x_4', 'y_4', 'z_4', 'x_5', 'y_5', 'z_5']
noise_std = [0.03, 0.015, 0.01, 0.05, 0.03, 0.02, 0.08, 0.04, 0.025, 0.1, 0.065, 0.035, 0.15, 0.09, 0.045, 0.2, 0.13, 0.05]

np.random.seed(config.seed)

## OOFのパスは適宜設定してください.

oof_df = pd.read_csv(os.path.join(config.output_dir, f"54_convnext_large", "oof_predictions.csv"))
# adding gausian noise
for i, target in enumerate(targets):
    oof_df.loc[:, target] += 0.5 * np.random.normal(0, noise_std[i], len(oof_df))
oof_df = oof_df.set_index("ID").loc[train_df["ID"].values].reset_index(drop=True)

test_preds_df = pd.read_csv(os.path.join(config.output_dir, f"54_convnext_large", "test_predictions.csv"))
# adding gausian noise
for i, target in enumerate(targets):
    test_preds_df.loc[:, target] += 0.5 * np.random.normal(0, noise_std[i], len(test_preds_df))
test_preds_df = test_preds_df.set_index("ID").loc[test_df["ID"].values].reset_index(drop=True)

columns = [f"convnext_large_v54_{col}" for col in oof_df.columns]
oof_df.columns = columns
test_preds_df.columns = columns

train_df = pd.concat([train_df, oof_df], axis=1)
test_df = pd.concat([test_df, test_preds_df], axis=1)

# %%
targets = ['x_0', 'y_0', 'z_0', 'x_1', 'y_1', 'z_1', 'x_2', 'y_2', 'z_2', 'x_3', 'y_3', 'z_3', 'x_4', 'y_4', 'z_4', 'x_5', 'y_5', 'z_5']
col_nouse = ["ID", "scene_id", "frame_id", "cluster"] + targets
col_touse = [col for col in train_df.columns if col not in col_nouse]

# %%
# MAEを計算
def evaluation(true_values, pred_values):
    abs_diff = abs(true_values - pred_values)
    mae = np.mean(abs_diff.reshape(-1,))
    return mae

def train_xgb(target):
    params = {
        "objective": "reg:squarederror",  # MAE can be used as evaluation metric
        "n_jobs": -1,
        "seed": config.seed,
        "learning_rate": config.learning_rate,
        "tree_method": "hist",
        "n_estimators": 10000,
        "early_stopping_rounds": 100,
        "eval_metric": "mae",
        "max_depth": config.max_depth,
        "min_child_weight": config.min_child_weight,
        "gamma": config.gamma,
        "reg_alpha": config.reg_alpha,
        "reg_lambda": config.reg_lambda,
        "subsample": config.subsample,
        "colsample_bytree": config.colsample_bytree,
    }

    oof_pred = np.zeros(len(train_df))
    y_pred = np.zeros(len(test_df))
    models = []
    cv_scores = {}

    sgkf = StratifiedGroupKFold(n_splits=config.n_folds, shuffle=True, random_state=config.seed)

    for fold, (train_index, test_index) in enumerate(sgkf.split(train_df, train_df["cluster"], groups=train_df["scene_id"])):

        print(f"====== fold {fold} ======")

        # TrainとTestに分割
        x_train, x_val = train_df.loc[train_index, col_touse], train_df.loc[test_index, col_touse]
        y_train, y_val = train_df.loc[train_index, target], train_df.loc[test_index, target]

        test = test_df[col_touse]

        model = XGBRegressor(**params)
        model.fit(
            x_train, y_train,
            eval_set=[(x_train, y_train), (x_val, y_val)],
            verbose=100
        )
        fold_pred = model.predict(x_val)
        score = evaluation(y_val.values, fold_pred)
        cv_scores[f"cv{fold}"] = score

        oof_pred[test_index] = fold_pred

        y_pred += model.predict(test) / config.n_folds

        print(f"cv score is {score}")

    oof_score = evaluation(train_df[target].values.reshape(-1), oof_pred)
    print(f"OOF score is {oof_score}")

    return oof_pred, y_pred, models

# %%
models_dict = {}
test_pred = []
oof_pred = []
for target in targets:
    print("=" * 50)
    print(f"# {target}")
    print("=" * 50)
    oof_preds_partial, y_pred_partial, models_partial = train_xgb(target)
    models_dict[target] = models_partial
    oof_pred.append(oof_preds_partial)
    test_pred.append(y_pred_partial)
# Out:
# ==================================================
# # x_0
# ==================================================
# ====== fold 0 ======
# [0]	validation_0-mae:2.75865	validation_1-mae:2.78447
# [100]	validation_0-mae:2.04721	validation_1-mae:2.06727
# [200]	validation_0-mae:1.51952	validation_1-mae:1.53474
# [300]	validation_0-mae:1.12764	validation_1-mae:1.13908
# [400]	validation_0-mae:0.83812	validation_1-mae:0.84695
# [500]	validation_0-mae:0.62383	validation_1-mae:0.63084
# [600]	validation_0-mae:0.46500	validation_1-mae:0.47058
# [700]	validation_0-mae:0.34802	validation_1-mae:0.35264
# [800]	validation_0-mae:0.26234	validation_1-mae:0.26631
# [900]	validation_0-mae:0.20029	validation_1-mae:0.20382
# [1000]	validation_0-mae:0.15578	validation_1-mae:0.15904
# [1100]	validation_0-mae:0.12445	validation_1-mae:0.12771
# [1200]	validation_0-mae:0.10277	validation_1-mae:0.10614
# [1300]	validation_0-mae:0.08812	validation_1-mae:0.09155
# [1400]	validation_0-mae:0.07839	validation_1-mae:0.08191
# [1500]	validation_0-mae:0.07203	validation_1-mae:0.07563
# [1600]	validation_0-mae:0.06792	validation_1-mae:0.07152
# [1700]	validation_0-mae:0.06532	validation_1-mae:0.06885
# [1800]	validation_0-mae:0.06367	validation_1-mae:0.06712
# [1900]	validation_0-mae:0.06261	validation_1-mae:0.06597
# [2000]	validation_0-mae:0.06193	validation_1-mae:0.06522
# [2100]	validation_0-mae:0.06149	validation_1-mae:0.06470
# [2200]	validation_0-mae:0.06119	validation_1-mae:0.06435
# [2300]	validation_0-mae:0.06099	validation_1-mae:0.06412
# [2400]	validation_0-mae:0.06084	validation_1-mae:0.06395
# [2500]	validation_0-mae:0.06072	validation_1-mae:0.06382
# [2600]	validation_0-mae:0.06063	validation_1-mae:0.06372
# [2700]	validation_0-mae:0.06056	validation_1-mae:0.06366
# [2800]	validation_0-mae:0.06052	validation_1-mae:0.06362
# [2900]	validation_0-mae:0.06048	validation_1-mae:0.06358
# [3000]	validation_0-mae:0.06045	validation_1-mae:0.06356
# [3100]	validation_0-mae:0.06043	validation_1-mae:0.06354
# [3200]	validation_0-mae:0.06040	validation_1-mae:0.06352
# [3300]	validation_0-mae:0.06039	validation_1-mae:0.06351
# [3400]	validation_0-mae:0.06038	validation_1-mae:0.06350
# [3500]	validation_0-mae:0.06036	validation_1-mae:0.06349
# [3600]	validation_0-mae:0.06035	validation_1-mae:0.06348
# [3700]	validation_0-mae:0.06034	validation_1-mae:0.06347
# [3800]	validation_0-mae:0.06033	validation_1-mae:0.06346
# [3900]	validation_0-mae:0.06032	validation_1-mae:0.06346
# [4000]	validation_0-mae:0.06032	validation_1-mae:0.06346
# [4100]	validation_0-mae:0.06031	validation_1-mae:0.06345
# [4200]	validation_0-mae:0.06030	validation_1-mae:0.06345
# [4300]	validation_0-mae:0.06030	validation_1-mae:0.06345
# [4400]	validation_0-mae:0.06030	validation_1-mae:0.06344
# [4500]	validation_0-mae:0.06029	validation_1-mae:0.06344
# [4600]	validation_0-mae:0.06029	validation_1-mae:0.06344
# [4700]	validation_0-mae:0.06029	validation_1-mae:0.06344
# [4800]	validation_0-mae:0.06028	validation_1-mae:0.06344
# [4900]	validation_0-mae:0.06028	validation_1-mae:0.06343
# [5000]	validation_0-mae:0.06027	validation_1-mae:0.06343
# [5100]	validation_0-mae:0.06027	validation_1-mae:0.06343
# [5200]	validation_0-mae:0.06027	validation_1-mae:0.06343
# [5300]	validation_0-mae:0.06027	validation_1-mae:0.06343
# [5400]	validation_0-mae:0.06026	validation_1-mae:0.06343
# [5500]	validation_0-mae:0.06026	validation_1-mae:0.06342
# [5600]	validation_0-mae:0.06026	validation_1-mae:0.06342
# [5700]	validation_0-mae:0.06026	validation_1-mae:0.06342
# [5727]	validation_0-mae:0.06026	validation_1-mae:0.06342
# cv score is 0.06342231517907944
# ====== fold 1 ======
# [0]	validation_0-mae:2.77483	validation_1-mae:2.72281
# [100]	validation_0-mae:2.05941	validation_1-mae:2.02117
# [200]	validation_0-mae:1.52863	validation_1-mae:1.50055
# [300]	validation_0-mae:1.13437	validation_1-mae:1.11385
# [400]	validation_0-mae:0.84307	validation_1-mae:0.82844
# [500]	validation_0-mae:0.62738	validation_1-mae:0.61741
# [600]	validation_0-mae:0.46752	validation_1-mae:0.46097
# [700]	validation_0-mae:0.34982	validation_1-mae:0.34589
# [800]	validation_0-mae:0.26354	validation_1-mae:0.26175
# [900]	validation_0-mae:0.20105	validation_1-mae:0.20108
# [1000]	validation_0-mae:0.15624	validation_1-mae:0.15777
# [1100]	validation_0-mae:0.12470	validation_1-mae:0.12730
# [1200]	validation_0-mae:0.10293	validation_1-mae:0.10623
# [1300]	validation_0-mae:0.08825	validation_1-mae:0.09200
# [1400]	validation_0-mae:0.07847	validation_1-mae:0.08255
# [1500]	validation_0-mae:0.07210	validation_1-mae:0.07634
# [1600]	validation_0-mae:0.06797	validation_1-mae:0.07231
# [1700]	validation_0-mae:0.06535	validation_1-mae:0.06975
# [1800]	validation_0-mae:0.06366	validation_1-mae:0.06810
# [1900]	validation_0-mae:0.06258	validation_1-mae:0.06702
# [2000]	validation_0-mae:0.06188	validation_1-mae:0.06630
# [2100]	validation_0-mae:0.06142	validation_1-mae:0.06583
# [2200]	validation_0-mae:0.06110	validation_1-mae:0.06551
# [2300]	validation_0-mae:0.06089	validation_1-mae:0.06530
# [2400]	validation_0-mae:0.06072	validation_1-mae:0.06513
# [2500]	validation_0-mae:0.06061	validation_1-mae:0.06501
# [2600]	validation_0-mae:0.06052	validation_1-mae:0.06493
# [2700]	validation_0-mae:0.06046	validation_1-mae:0.06487
# [2800]	validation_0-mae:0.06041	validation_1-mae:0.06482
# [2900]	validation_0-mae:0.06037	validation_1-mae:0.06478
# [3000]	validation_0-mae:0.06034	validation_1-mae:0.06475
# [3100]	validation_0-mae:0.06032	validation_1-mae:0.06473
# [3200]	validation_0-mae:0.06030	validation_1-mae:0.06472
# [3300]	validation_0-mae:0.06029	validation_1-mae:0.06470
# [3400]	validation_0-mae:0.06028	validation_1-mae:0.06470
# [3500]	validation_0-mae:0.06027	validation_1-mae:0.06469
# [3600]	validation_0-mae:0.06026	validation_1-mae:0.06468
# [3700]	validation_0-mae:0.06026	validation_1-mae:0.06467
# [3800]	validation_0-mae:0.06024	validation_1-mae:0.06466
# [3900]	validation_0-mae:0.06024	validation_1-mae:0.06466
# [4000]	validation_0-mae:0.06023	validation_1-mae:0.06465
# [4100]	validation_0-mae:0.06023	validation_1-mae:0.06465
# [4200]	validation_0-mae:0.06022	validation_1-mae:0.06465
# [4300]	validation_0-mae:0.06022	validation_1-mae:0.06464
# [4400]	validation_0-mae:0.06022	validation_1-mae:0.06464
# [4500]	validation_0-mae:0.06021	validation_1-mae:0.06463
# [4600]	validation_0-mae:0.06021	validation_1-mae:0.06463
# [4700]	validation_0-mae:0.06021	validation_1-mae:0.06463
# [4800]	validation_0-mae:0.06021	validation_1-mae:0.06463
# [4900]	validation_0-mae:0.06021	validation_1-mae:0.06463
# [5000]	validation_0-mae:0.06020	validation_1-mae:0.06463
# [5100]	validation_0-mae:0.06020	validation_1-mae:0.06462
# [5200]	validation_0-mae:0.06020	validation_1-mae:0.06462
# [5300]	validation_0-mae:0.06019	validation_1-mae:0.06462
# [5400]	validation_0-mae:0.06019	validation_1-mae:0.06462
# [5500]	validation_0-mae:0.06019	validation_1-mae:0.06462
# [5600]	validation_0-mae:0.06019	validation_1-mae:0.06461
# [5700]	validation_0-mae:0.06019	validation_1-mae:0.06461
# [5800]	validation_0-mae:0.06019	validation_1-mae:0.06461
# [5900]	validation_0-mae:0.06018	validation_1-mae:0.06461
# [6000]	validation_0-mae:0.06018	validation_1-mae:0.06461
# [6100]	validation_0-mae:0.06018	validation_1-mae:0.06461
# [6200]	validation_0-mae:0.06018	validation_1-mae:0.06461
# [6300]	validation_0-mae:0.06018	validation_1-mae:0.06461
# [6400]	validation_0-mae:0.06018	validation_1-mae:0.06460
# [6500]	validation_0-mae:0.06018	validation_1-mae:0.06460
# [6600]	validation_0-mae:0.06017	validation_1-mae:0.06460
# [6700]	validation_0-mae:0.06017	validation_1-mae:0.06460
# [6800]	validation_0-mae:0.06017	validation_1-mae:0.06460
# [6900]	validation_0-mae:0.06017	validation_1-mae:0.06460
# [7000]	validation_0-mae:0.06017	validation_1-mae:0.06460
# [7100]	validation_0-mae:0.06017	validation_1-mae:0.06460
# [7200]	validation_0-mae:0.06017	validation_1-mae:0.06460
# [7300]	validation_0-mae:0.06017	validation_1-mae:0.06459
# [7400]	validation_0-mae:0.06017	validation_1-mae:0.06459
# [7500]	validation_0-mae:0.06016	validation_1-mae:0.06459
# [7600]	validation_0-mae:0.06016	validation_1-mae:0.06459
# [7700]	validation_0-mae:0.06016	validation_1-mae:0.06459
# [7800]	validation_0-mae:0.06016	validation_1-mae:0.06459
# [7900]	validation_0-mae:0.06016	validation_1-mae:0.06459
# [8000]	validation_0-mae:0.06016	validation_1-mae:0.06459
# [8100]	validation_0-mae:0.06016	validation_1-mae:0.06459
# [8200]	validation_0-mae:0.06016	validation_1-mae:0.06459
# [8300]	validation_0-mae:0.06015	validation_1-mae:0.06459
# [8400]	validation_0-mae:0.06015	validation_1-mae:0.06458
# [8475]	validation_0-mae:0.06015	validation_1-mae:0.06459
# cv score is 0.0645848890707465
# ====== fold 2 ======
# [0]	validation_0-mae:2.76380	validation_1-mae:2.76369
# [100]	validation_0-mae:2.05112	validation_1-mae:2.05246
# [200]	validation_0-mae:1.52246	validation_1-mae:1.52470
# [300]	validation_0-mae:1.12983	validation_1-mae:1.13242
# [400]	validation_0-mae:0.83974	validation_1-mae:0.84273
# [500]	validation_0-mae:0.62503	validation_1-mae:0.62825
# [600]	validation_0-mae:0.46589	validation_1-mae:0.46922
# [700]	validation_0-mae:0.34873	validation_1-mae:0.35217
# [800]	validation_0-mae:0.26291	validation_1-mae:0.26644
# [900]	validation_0-mae:0.20077	validation_1-mae:0.20435
# [1000]	validation_0-mae:0.15625	validation_1-mae:0.15971
# [1100]	validation_0-mae:0.12490	validation_1-mae:0.12821
# [1200]	validation_0-mae:0.10323	validation_1-mae:0.10634
# [1300]	validation_0-mae:0.08855	validation_1-mae:0.09156
# [1400]	validation_0-mae:0.07882	validation_1-mae:0.08169
# [1500]	validation_0-mae:0.07247	validation_1-mae:0.07519
# [1600]	validation_0-mae:0.06837	validation_1-mae:0.07098
# [1700]	validation_0-mae:0.06573	validation_1-mae:0.06828
# [1800]	validation_0-mae:0.06406	validation_1-mae:0.06655
# [1900]	validation_0-mae:0.06297	validation_1-mae:0.06543
# [2000]	validation_0-mae:0.06225	validation_1-mae:0.06471
# [2100]	validation_0-mae:0.06179	validation_1-mae:0.06424
# [2200]	validation_0-mae:0.06147	validation_1-mae:0.06390
# [2300]	validation_0-mae:0.06126	validation_1-mae:0.06368
# [2400]	validation_0-mae:0.06110	validation_1-mae:0.06352
# [2500]	validation_0-mae:0.06097	validation_1-mae:0.06340
# [2600]	validation_0-mae:0.06088	validation_1-mae:0.06332
# [2700]	validation_0-mae:0.06082	validation_1-mae:0.06326
# [2800]	validation_0-mae:0.06077	validation_1-mae:0.06322
# [2900]	validation_0-mae:0.06073	validation_1-mae:0.06320
# [3000]	validation_0-mae:0.06070	validation_1-mae:0.06317
# [3100]	validation_0-mae:0.06068	validation_1-mae:0.06315
# [3200]	validation_0-mae:0.06066	validation_1-mae:0.06314
# [3300]	validation_0-mae:0.06065	validation_1-mae:0.06313
# [3400]	validation_0-mae:0.06064	validation_1-mae:0.06313
# [3500]	validation_0-mae:0.06063	validation_1-mae:0.06312
# [3600]	validation_0-mae:0.06061	validation_1-mae:0.06311
# [3700]	validation_0-mae:0.06061	validation_1-mae:0.06310
# [3800]	validation_0-mae:0.06060	validation_1-mae:0.06310
# [3900]	validation_0-mae:0.06059	validation_1-mae:0.06309
# [4000]	validation_0-mae:0.06059	validation_1-mae:0.06309
# [4100]	validation_0-mae:0.06058	validation_1-mae:0.06309
# [4200]	validation_0-mae:0.06058	validation_1-mae:0.06308
# [4300]	validation_0-mae:0.06057	validation_1-mae:0.06308
# [4400]	validation_0-mae:0.06057	validation_1-mae:0.06307
# [4500]	validation_0-mae:0.06057	validation_1-mae:0.06307
# [4600]	validation_0-mae:0.06056	validation_1-mae:0.06307
# [4700]	validation_0-mae:0.06056	validation_1-mae:0.06307
# [4800]	validation_0-mae:0.06056	validation_1-mae:0.06307
# [4900]	validation_0-mae:0.06055	validation_1-mae:0.06306
# [5000]	validation_0-mae:0.06055	validation_1-mae:0.06306
# [5100]	validation_0-mae:0.06055	validation_1-mae:0.06306
# [5200]	validation_0-mae:0.06054	validation_1-mae:0.06305
# [5300]	validation_0-mae:0.06054	validation_1-mae:0.06305
# [5400]	validation_0-mae:0.06054	validation_1-mae:0.06305
# [5435]	validation_0-mae:0.06054	validation_1-mae:0.06305
# cv score is 0.06305256240706178
# ====== fold 3 ======
# [0]	validation_0-mae:2.76804	validation_1-mae:2.75423
# [100]	validation_0-mae:2.05441	validation_1-mae:2.04389
# [200]	validation_0-mae:1.52504	validation_1-mae:1.51711
# [300]	validation_0-mae:1.13174	validation_1-mae:1.12551
# [400]	validation_0-mae:0.84117	validation_1-mae:0.83634
# [500]	validation_0-mae:0.62608	validation_1-mae:0.62225
# [600]	validation_0-mae:0.46672	validation_1-mae:0.46356
# [700]	validation_0-mae:0.34936	validation_1-mae:0.34675
# [800]	validation_0-mae:0.26339	validation_1-mae:0.26113
# [900]	validation_0-mae:0.20109	validation_1-mae:0.19936
# [1000]	validation_0-mae:0.15640	validation_1-mae:0.15538
# [1100]	validation_0-mae:0.12486	validation_1-mae:0.12472
# [1200]	validation_0-mae:0.10304	validation_1-mae:0.10372
# [1300]	validation_0-mae:0.08830	validation_1-mae:0.08958
# [1400]	validation_0-mae:0.07850	validation_1-mae:0.08019
# [1500]	validation_0-mae:0.07212	validation_1-mae:0.07421
# [1600]	validation_0-mae:0.06802	validation_1-mae:0.07046
# [1700]	validation_0-mae:0.06542	validation_1-mae:0.06817
# [1800]	validation_0-mae:0.06375	validation_1-mae:0.06675
# [1900]	validation_0-mae:0.06268	validation_1-mae:0.06587
# [2000]	validation_0-mae:0.06198	validation_1-mae:0.06532
# [2100]	validation_0-mae:0.06152	validation_1-mae:0.06497
# [2200]	validation_0-mae:0.06120	validation_1-mae:0.06475
# [2300]	validation_0-mae:0.06101	validation_1-mae:0.06462
# [2400]	validation_0-mae:0.06086	validation_1-mae:0.06453
# [2500]	validation_0-mae:0.06074	validation_1-mae:0.06446
# [2600]	validation_0-mae:0.06064	validation_1-mae:0.06441
# [2700]	validation_0-mae:0.06057	validation_1-mae:0.06437
# [2800]	validation_0-mae:0.06052	validation_1-mae:0.06434
# [2900]	validation_0-mae:0.06048	validation_1-mae:0.06433
# [3000]	validation_0-mae:0.06044	validation_1-mae:0.06431
# [3100]	validation_0-mae:0.06041	validation_1-mae:0.06430
# [3200]	validation_0-mae:0.06040	validation_1-mae:0.06429
# [3300]	validation_0-mae:0.06038	validation_1-mae:0.06429
# [3400]	validation_0-mae:0.06037	validation_1-mae:0.06428
# [3500]	validation_0-mae:0.06036	validation_1-mae:0.06427
# [3600]	validation_0-mae:0.06035	validation_1-mae:0.06427
# [3700]	validation_0-mae:0.06034	validation_1-mae:0.06427
# [3800]	validation_0-mae:0.06033	validation_1-mae:0.06426
# [3900]	validation_0-mae:0.06033	validation_1-mae:0.06426
# [4000]	validation_0-mae:0.06032	validation_1-mae:0.06426
# [4100]	validation_0-mae:0.06032	validation_1-mae:0.06426
# [4200]	validation_0-mae:0.06031	validation_1-mae:0.06426
# [4300]	validation_0-mae:0.06031	validation_1-mae:0.06426
# [4400]	validation_0-mae:0.06030	validation_1-mae:0.06425
# [4500]	validation_0-mae:0.06030	validation_1-mae:0.06425
# [4600]	validation_0-mae:0.06030	validation_1-mae:0.06425
# [4700]	validation_0-mae:0.06029	validation_1-mae:0.06425
# [4734]	validation_0-mae:0.06029	validation_1-mae:0.06425
# cv score is 0.06425115803445909
# ====== fold 4 ======
# [0]	validation_0-mae:2.75584	validation_1-mae:2.79627
# [100]	validation_0-mae:2.04528	validation_1-mae:2.07654
# [200]	validation_0-mae:1.51813	validation_1-mae:1.54273
# [300]	validation_0-mae:1.12662	validation_1-mae:1.14595
# [400]	validation_0-mae:0.83737	validation_1-mae:0.85269
# [500]	validation_0-mae:0.62331	validation_1-mae:0.63548
# [600]	validation_0-mae:0.46464	validation_1-mae:0.47448
# [700]	validation_0-mae:0.34781	validation_1-mae:0.35586
# [800]	validation_0-mae:0.26222	validation_1-mae:0.26898
# [900]	validation_0-mae:0.20026	validation_1-mae:0.20601
# [1000]	validation_0-mae:0.15583	validation_1-mae:0.16056
# [1100]	validation_0-mae:0.12459	validation_1-mae:0.12845
# [1200]	validation_0-mae:0.10295	validation_1-mae:0.10632
# [1300]	validation_0-mae:0.08829	validation_1-mae:0.09135
# [1400]	validation_0-mae:0.07852	validation_1-mae:0.08141
# [1500]	validation_0-mae:0.07219	validation_1-mae:0.07489
# [1600]	validation_0-mae:0.06813	validation_1-mae:0.07065
# [1700]	validation_0-mae:0.06556	validation_1-mae:0.06797
# [1800]	validation_0-mae:0.06392	validation_1-mae:0.06629
# [1900]	validation_0-mae:0.06288	validation_1-mae:0.06521
# [2000]	validation_0-mae:0.06220	validation_1-mae:0.06452
# [2100]	validation_0-mae:0.06175	validation_1-mae:0.06408
# [2200]	validation_0-mae:0.06146	validation_1-mae:0.06380
# [2300]	validation_0-mae:0.06126	validation_1-mae:0.06362
# [2400]	validation_0-mae:0.06111	validation_1-mae:0.06349
# [2500]	validation_0-mae:0.06100	validation_1-mae:0.06340
# [2600]	validation_0-mae:0.06092	validation_1-mae:0.06333
# [2700]	validation_0-mae:0.06084	validation_1-mae:0.06328
# [2800]	validation_0-mae:0.06079	validation_1-mae:0.06324
# [2900]	validation_0-mae:0.06075	validation_1-mae:0.06321
# [3000]	validation_0-mae:0.06072	validation_1-mae:0.06319
# [3100]	validation_0-mae:0.06070	validation_1-mae:0.06318
# [3200]	validation_0-mae:0.06068	validation_1-mae:0.06316
# [3300]	validation_0-mae:0.06066	validation_1-mae:0.06315
# [3400]	validation_0-mae:0.06065	validation_1-mae:0.06314
# [3500]	validation_0-mae:0.06063	validation_1-mae:0.06313
# [3600]	validation_0-mae:0.06062	validation_1-mae:0.06312
# [3700]	validation_0-mae:0.06062	validation_1-mae:0.06312
# [3800]	validation_0-mae:0.06060	validation_1-mae:0.06312
# [3900]	validation_0-mae:0.06060	validation_1-mae:0.06311
# [4000]	validation_0-mae:0.06059	validation_1-mae:0.06311
# [4100]	validation_0-mae:0.06059	validation_1-mae:0.06311
# [4200]	validation_0-mae:0.06058	validation_1-mae:0.06310
# [4300]	validation_0-mae:0.06058	validation_1-mae:0.06310
# [4400]	validation_0-mae:0.06057	validation_1-mae:0.06310
# [4500]	validation_0-mae:0.06057	validation_1-mae:0.06309
# [4600]	validation_0-mae:0.06056	validation_1-mae:0.06309
# [4700]	validation_0-mae:0.06056	validation_1-mae:0.06309
# [4800]	validation_0-mae:0.06055	validation_1-mae:0.06309
# [4900]	validation_0-mae:0.06055	validation_1-mae:0.06309
# [5000]	validation_0-mae:0.06055	validation_1-mae:0.06309
# [5100]	validation_0-mae:0.06055	validation_1-mae:0.06309
# [5200]	validation_0-mae:0.06054	validation_1-mae:0.06308
# [5300]	validation_0-mae:0.06054	validation_1-mae:0.06308
# [5400]	validation_0-mae:0.06053	validation_1-mae:0.06308
# [5478]	validation_0-mae:0.06053	validation_1-mae:0.06308
# cv score is 0.06308245568209055
# OOF score is 0.0636777077900308
# ==================================================
# # y_0
# ==================================================
# ====== fold 0 ======
# [0]	validation_0-mae:0.05923	validation_1-mae:0.06088
# [100]	validation_0-mae:0.05076	validation_1-mae:0.05233
# [200]	validation_0-mae:0.04483	validation_1-mae:0.04637
# [300]	validation_0-mae:0.04078	validation_1-mae:0.04232
# [400]	validation_0-mae:0.03800	validation_1-mae:0.03950
# [500]	validation_0-mae:0.03620	validation_1-mae:0.03763
# [600]	validation_0-mae:0.03506	validation_1-mae:0.03646
# [700]	validation_0-mae:0.03430	validation_1-mae:0.03572
# [800]	validation_0-mae:0.03382	validation_1-mae:0.03524
# [900]	validation_0-mae:0.03347	validation_1-mae:0.03491
# [1000]	validation_0-mae:0.03325	validation_1-mae:0.03470
# [1100]	validation_0-mae:0.03310	validation_1-mae:0.03455
# [1200]	validation_0-mae:0.03299	validation_1-mae:0.03444
# [1300]	validation_0-mae:0.03291	validation_1-mae:0.03436
# [1400]	validation_0-mae:0.03285	validation_1-mae:0.03431
# [1500]	validation_0-mae:0.03281	validation_1-mae:0.03427
# [1600]	validation_0-mae:0.03278	validation_1-mae:0.03425
# [1700]	validation_0-mae:0.03276	validation_1-mae:0.03423
# [1800]	validation_0-mae:0.03275	validation_1-mae:0.03423
# [1900]	validation_0-mae:0.03274	validation_1-mae:0.03422
# [2000]	validation_0-mae:0.03273	validation_1-mae:0.03421
# [2100]	validation_0-mae:0.03273	validation_1-mae:0.03421
# [2200]	validation_0-mae:0.03273	validation_1-mae:0.03421
# [2300]	validation_0-mae:0.03273	validation_1-mae:0.03421
# [2400]	validation_0-mae:0.03272	validation_1-mae:0.03421
# [2500]	validation_0-mae:0.03272	validation_1-mae:0.03420
# [2600]	validation_0-mae:0.03272	validation_1-mae:0.03420
# [2700]	validation_0-mae:0.03271	validation_1-mae:0.03420
# [2800]	validation_0-mae:0.03271	validation_1-mae:0.03420
# [2900]	validation_0-mae:0.03271	validation_1-mae:0.03420
# [3000]	validation_0-mae:0.03271	validation_1-mae:0.03420
# [3100]	validation_0-mae:0.03271	validation_1-mae:0.03419
# [3200]	validation_0-mae:0.03271	validation_1-mae:0.03419
# [3300]	validation_0-mae:0.03270	validation_1-mae:0.03419
# [3400]	validation_0-mae:0.03270	validation_1-mae:0.03419
# [3500]	validation_0-mae:0.03270	validation_1-mae:0.03419
# [3600]	validation_0-mae:0.03270	validation_1-mae:0.03419
# [3700]	validation_0-mae:0.03270	validation_1-mae:0.03419
# [3800]	validation_0-mae:0.03270	validation_1-mae:0.03419
# [3900]	validation_0-mae:0.03270	validation_1-mae:0.03419
# [4000]	validation_0-mae:0.03270	validation_1-mae:0.03419
# [4100]	validation_0-mae:0.03270	validation_1-mae:0.03419
# [4112]	validation_0-mae:0.03270	validation_1-mae:0.03419
# cv score is 0.034187305614931364
# ====== fold 1 ======
# [0]	validation_0-mae:0.05942	validation_1-mae:0.06017
# [100]	validation_0-mae:0.05095	validation_1-mae:0.05171
# [200]	validation_0-mae:0.04505	validation_1-mae:0.04574
# [300]	validation_0-mae:0.04102	validation_1-mae:0.04168
# [400]	validation_0-mae:0.03826	validation_1-mae:0.03894
# [500]	validation_0-mae:0.03644	validation_1-mae:0.03716
# [600]	validation_0-mae:0.03530	validation_1-mae:0.03608
# [700]	validation_0-mae:0.03454	validation_1-mae:0.03535
# [800]	validation_0-mae:0.03406	validation_1-mae:0.03491
# [900]	validation_0-mae:0.03372	validation_1-mae:0.03461
# [1000]	validation_0-mae:0.03349	validation_1-mae:0.03443
# [1100]	validation_0-mae:0.03333	validation_1-mae:0.03431
# [1200]	validation_0-mae:0.03322	validation_1-mae:0.03422
# [1300]	validation_0-mae:0.03313	validation_1-mae:0.03414
# [1400]	validation_0-mae:0.03308	validation_1-mae:0.03410
# [1500]	validation_0-mae:0.03304	validation_1-mae:0.03406
# [1600]	validation_0-mae:0.03301	validation_1-mae:0.03404
# [1700]	validation_0-mae:0.03299	validation_1-mae:0.03402
# [1800]	validation_0-mae:0.03297	validation_1-mae:0.03401
# [1900]	validation_0-mae:0.03296	validation_1-mae:0.03400
# [2000]	validation_0-mae:0.03295	validation_1-mae:0.03400
# [2100]	validation_0-mae:0.03295	validation_1-mae:0.03399
# [2200]	validation_0-mae:0.03294	validation_1-mae:0.03399
# [2300]	validation_0-mae:0.03294	validation_1-mae:0.03399
# [2400]	validation_0-mae:0.03293	validation_1-mae:0.03398
# [2500]	validation_0-mae:0.03293	validation_1-mae:0.03398
# [2600]	validation_0-mae:0.03293	validation_1-mae:0.03398
# [2700]	validation_0-mae:0.03292	validation_1-mae:0.03397
# [2800]	validation_0-mae:0.03292	validation_1-mae:0.03397
# [2900]	validation_0-mae:0.03292	validation_1-mae:0.03397
# [3000]	validation_0-mae:0.03292	validation_1-mae:0.03397
# [3100]	validation_0-mae:0.03292	validation_1-mae:0.03397
# [3200]	validation_0-mae:0.03291	validation_1-mae:0.03397
# [3300]	validation_0-mae:0.03291	validation_1-mae:0.03396
# [3400]	validation_0-mae:0.03291	validation_1-mae:0.03396
# [3500]	validation_0-mae:0.03291	validation_1-mae:0.03396
# [3600]	validation_0-mae:0.03291	validation_1-mae:0.03396
# [3700]	validation_0-mae:0.03291	validation_1-mae:0.03396
# [3800]	validation_0-mae:0.03291	validation_1-mae:0.03396
# [3854]	validation_0-mae:0.03291	validation_1-mae:0.03396
# cv score is 0.033959087404249556
# ====== fold 2 ======
# [0]	validation_0-mae:0.05982	validation_1-mae:0.05853
# [100]	validation_0-mae:0.05132	validation_1-mae:0.05017
# [200]	validation_0-mae:0.04539	validation_1-mae:0.04433
# [300]	validation_0-mae:0.04133	validation_1-mae:0.04038
# [400]	validation_0-mae:0.03855	validation_1-mae:0.03766
# [500]	validation_0-mae:0.03671	validation_1-mae:0.03594
# [600]	validation_0-mae:0.03557	validation_1-mae:0.03488
# [700]	validation_0-mae:0.03480	validation_1-mae:0.03417
# [800]	validation_0-mae:0.03431	validation_1-mae:0.03372
# [900]	validation_0-mae:0.03396	validation_1-mae:0.03341
# [1000]	validation_0-mae:0.03373	validation_1-mae:0.03320
# [1100]	validation_0-mae:0.03358	validation_1-mae:0.03306
# [1200]	validation_0-mae:0.03345	validation_1-mae:0.03296
# [1300]	validation_0-mae:0.03336	validation_1-mae:0.03288
# [1400]	validation_0-mae:0.03330	validation_1-mae:0.03282
# [1500]	validation_0-mae:0.03326	validation_1-mae:0.03279
# [1600]	validation_0-mae:0.03323	validation_1-mae:0.03276
# [1700]	validation_0-mae:0.03321	validation_1-mae:0.03275
# [1800]	validation_0-mae:0.03320	validation_1-mae:0.03274
# [1900]	validation_0-mae:0.03319	validation_1-mae:0.03273
# [2000]	validation_0-mae:0.03318	validation_1-mae:0.03272
# [2100]	validation_0-mae:0.03317	validation_1-mae:0.03272
# [2200]	validation_0-mae:0.03317	validation_1-mae:0.03271
# [2300]	validation_0-mae:0.03317	validation_1-mae:0.03271
# [2400]	validation_0-mae:0.03316	validation_1-mae:0.03271
# [2500]	validation_0-mae:0.03316	validation_1-mae:0.03270
# [2600]	validation_0-mae:0.03315	validation_1-mae:0.03270
# [2700]	validation_0-mae:0.03315	validation_1-mae:0.03270
# [2800]	validation_0-mae:0.03315	validation_1-mae:0.03269
# [2900]	validation_0-mae:0.03315	validation_1-mae:0.03269
# [3000]	validation_0-mae:0.03314	validation_1-mae:0.03269
# [3100]	validation_0-mae:0.03314	validation_1-mae:0.03269
# [3200]	validation_0-mae:0.03314	validation_1-mae:0.03268
# [3300]	validation_0-mae:0.03314	validation_1-mae:0.03268
# [3400]	validation_0-mae:0.03314	validation_1-mae:0.03268
# [3500]	validation_0-mae:0.03314	validation_1-mae:0.03268
# [3600]	validation_0-mae:0.03313	validation_1-mae:0.03268
# [3700]	validation_0-mae:0.03313	validation_1-mae:0.03268
# [3800]	validation_0-mae:0.03313	validation_1-mae:0.03267
# [3900]	validation_0-mae:0.03313	validation_1-mae:0.03267
# [4000]	validation_0-mae:0.03313	validation_1-mae:0.03267
# [4100]	validation_0-mae:0.03313	validation_1-mae:0.03267
# [4200]	validation_0-mae:0.03313	validation_1-mae:0.03267
# [4300]	validation_0-mae:0.03313	validation_1-mae:0.03267
# [4400]	validation_0-mae:0.03313	validation_1-mae:0.03267
# [4500]	validation_0-mae:0.03312	validation_1-mae:0.03267
# [4600]	validation_0-mae:0.03312	validation_1-mae:0.03266
# [4700]	validation_0-mae:0.03312	validation_1-mae:0.03266
# [4800]	validation_0-mae:0.03312	validation_1-mae:0.03266
# [4900]	validation_0-mae:0.03312	validation_1-mae:0.03266
# [5000]	validation_0-mae:0.03312	validation_1-mae:0.03266
# [5100]	validation_0-mae:0.03312	validation_1-mae:0.03266
# [5200]	validation_0-mae:0.03312	validation_1-mae:0.03266
# [5300]	validation_0-mae:0.03312	validation_1-mae:0.03266
# [5400]	validation_0-mae:0.03312	validation_1-mae:0.03266
# [5500]	validation_0-mae:0.03312	validation_1-mae:0.03266
# [5566]	validation_0-mae:0.03311	validation_1-mae:0.03266
# cv score is 0.03265529049503651
# ====== fold 3 ======
# [0]	validation_0-mae:0.05983	validation_1-mae:0.05855
# [100]	validation_0-mae:0.05132	validation_1-mae:0.05013
# [200]	validation_0-mae:0.04536	validation_1-mae:0.04438
# [300]	validation_0-mae:0.04127	validation_1-mae:0.04051
# [400]	validation_0-mae:0.03848	validation_1-mae:0.03796
# [500]	validation_0-mae:0.03663	validation_1-mae:0.03631
# [600]	validation_0-mae:0.03547	validation_1-mae:0.03530
# [700]	validation_0-mae:0.03471	validation_1-mae:0.03464
# [800]	validation_0-mae:0.03422	validation_1-mae:0.03425
# [900]	validation_0-mae:0.03387	validation_1-mae:0.03399
# [1000]	validation_0-mae:0.03363	validation_1-mae:0.03383
# [1100]	validation_0-mae:0.03347	validation_1-mae:0.03373
# [1200]	validation_0-mae:0.03335	validation_1-mae:0.03365
# [1300]	validation_0-mae:0.03326	validation_1-mae:0.03360
# [1400]	validation_0-mae:0.03321	validation_1-mae:0.03356
# [1500]	validation_0-mae:0.03317	validation_1-mae:0.03355
# [1600]	validation_0-mae:0.03314	validation_1-mae:0.03353
# [1700]	validation_0-mae:0.03312	validation_1-mae:0.03352
# [1800]	validation_0-mae:0.03310	validation_1-mae:0.03351
# [1900]	validation_0-mae:0.03309	validation_1-mae:0.03350
# [2000]	validation_0-mae:0.03309	validation_1-mae:0.03350
# [2100]	validation_0-mae:0.03308	validation_1-mae:0.03350
# [2200]	validation_0-mae:0.03308	validation_1-mae:0.03349
# [2300]	validation_0-mae:0.03307	validation_1-mae:0.03349
# [2400]	validation_0-mae:0.03307	validation_1-mae:0.03349
# [2500]	validation_0-mae:0.03307	validation_1-mae:0.03349
# [2600]	validation_0-mae:0.03306	validation_1-mae:0.03348
# [2700]	validation_0-mae:0.03306	validation_1-mae:0.03348
# [2800]	validation_0-mae:0.03306	validation_1-mae:0.03348
# [2900]	validation_0-mae:0.03306	validation_1-mae:0.03348
# [3000]	validation_0-mae:0.03305	validation_1-mae:0.03348
# [3100]	validation_0-mae:0.03305	validation_1-mae:0.03348
# [3200]	validation_0-mae:0.03305	validation_1-mae:0.03347
# [3300]	validation_0-mae:0.03305	validation_1-mae:0.03347
# [3400]	validation_0-mae:0.03305	validation_1-mae:0.03347
# [3500]	validation_0-mae:0.03305	validation_1-mae:0.03347
# [3600]	validation_0-mae:0.03304	validation_1-mae:0.03347
# [3700]	validation_0-mae:0.03304	validation_1-mae:0.03347
# [3800]	validation_0-mae:0.03304	validation_1-mae:0.03347
# [3900]	validation_0-mae:0.03304	validation_1-mae:0.03347
# [3941]	validation_0-mae:0.03304	validation_1-mae:0.03347
# cv score is 0.03346845687017174
# ====== fold 4 ======
# [0]	validation_0-mae:0.05953	validation_1-mae:0.05971
# [100]	validation_0-mae:0.05113	validation_1-mae:0.05134
# [200]	validation_0-mae:0.04524	validation_1-mae:0.04548
# [300]	validation_0-mae:0.04120	validation_1-mae:0.04143
# [400]	validation_0-mae:0.03845	validation_1-mae:0.03869
# [500]	validation_0-mae:0.03664	validation_1-mae:0.03689
# [600]	validation_0-mae:0.03549	validation_1-mae:0.03575
# [700]	validation_0-mae:0.03472	validation_1-mae:0.03499
# [800]	validation_0-mae:0.03423	validation_1-mae:0.03449
# [900]	validation_0-mae:0.03389	validation_1-mae:0.03413
# [1000]	validation_0-mae:0.03367	validation_1-mae:0.03388
# [1100]	validation_0-mae:0.03351	validation_1-mae:0.03370
# [1200]	validation_0-mae:0.03340	validation_1-mae:0.03357
# [1300]	validation_0-mae:0.03331	validation_1-mae:0.03348
# [1400]	validation_0-mae:0.03326	validation_1-mae:0.03341
# [1500]	validation_0-mae:0.03322	validation_1-mae:0.03337
# [1600]	validation_0-mae:0.03319	validation_1-mae:0.03333
# [1700]	validation_0-mae:0.03317	validation_1-mae:0.03331
# [1800]	validation_0-mae:0.03316	validation_1-mae:0.03329
# [1900]	validation_0-mae:0.03315	validation_1-mae:0.03328
# [2000]	validation_0-mae:0.03314	validation_1-mae:0.03327
# [2100]	validation_0-mae:0.03313	validation_1-mae:0.03326
# [2200]	validation_0-mae:0.03312	validation_1-mae:0.03326
# [2300]	validation_0-mae:0.03312	validation_1-mae:0.03325
# [2400]	validation_0-mae:0.03312	validation_1-mae:0.03325
# [2500]	validation_0-mae:0.03312	validation_1-mae:0.03324
# [2600]	validation_0-mae:0.03311	validation_1-mae:0.03324
# [2700]	validation_0-mae:0.03311	validation_1-mae:0.03324
# [2800]	validation_0-mae:0.03311	validation_1-mae:0.03324
# [2900]	validation_0-mae:0.03310	validation_1-mae:0.03324
# [3000]	validation_0-mae:0.03310	validation_1-mae:0.03323
# [3100]	validation_0-mae:0.03310	validation_1-mae:0.03323
# [3200]	validation_0-mae:0.03310	validation_1-mae:0.03323
# [3300]	validation_0-mae:0.03310	validation_1-mae:0.03323
# [3400]	validation_0-mae:0.03309	validation_1-mae:0.03322
# [3500]	validation_0-mae:0.03309	validation_1-mae:0.03322
# [3600]	validation_0-mae:0.03309	validation_1-mae:0.03322
# [3700]	validation_0-mae:0.03309	validation_1-mae:0.03322
# [3800]	validation_0-mae:0.03309	validation_1-mae:0.03322
# [3900]	validation_0-mae:0.03309	validation_1-mae:0.03322
# [4000]	validation_0-mae:0.03308	validation_1-mae:0.03321
# [4100]	validation_0-mae:0.03308	validation_1-mae:0.03321
# [4200]	validation_0-mae:0.03308	validation_1-mae:0.03321
# [4300]	validation_0-mae:0.03308	validation_1-mae:0.03321
# [4400]	validation_0-mae:0.03308	validation_1-mae:0.03321
# [4500]	validation_0-mae:0.03308	validation_1-mae:0.03321
# [4600]	validation_0-mae:0.03308	validation_1-mae:0.03321
# [4700]	validation_0-mae:0.03308	validation_1-mae:0.03321
# [4800]	validation_0-mae:0.03308	validation_1-mae:0.03321
# [4900]	validation_0-mae:0.03308	validation_1-mae:0.03321
# [5000]	validation_0-mae:0.03307	validation_1-mae:0.03320
# [5100]	validation_0-mae:0.03307	validation_1-mae:0.03320
# [5200]	validation_0-mae:0.03307	validation_1-mae:0.03320
# [5300]	validation_0-mae:0.03307	validation_1-mae:0.03320
# [5400]	validation_0-mae:0.03307	validation_1-mae:0.03320
# [5500]	validation_0-mae:0.03307	validation_1-mae:0.03320
# [5600]	validation_0-mae:0.03307	validation_1-mae:0.03320
# [5700]	validation_0-mae:0.03307	validation_1-mae:0.03320
# [5800]	validation_0-mae:0.03307	validation_1-mae:0.03320
# [5900]	validation_0-mae:0.03307	validation_1-mae:0.03320
# [6000]	validation_0-mae:0.03307	validation_1-mae:0.03320
# [6100]	validation_0-mae:0.03307	validation_1-mae:0.03320
# [6200]	validation_0-mae:0.03306	validation_1-mae:0.03319
# [6300]	validation_0-mae:0.03306	validation_1-mae:0.03319
# [6400]	validation_0-mae:0.03306	validation_1-mae:0.03319
# [6500]	validation_0-mae:0.03306	validation_1-mae:0.03319
# [6600]	validation_0-mae:0.03306	validation_1-mae:0.03319
# [6700]	validation_0-mae:0.03306	validation_1-mae:0.03319
# [6800]	validation_0-mae:0.03306	validation_1-mae:0.03319
# [6900]	validation_0-mae:0.03306	validation_1-mae:0.03319
# [7000]	validation_0-mae:0.03306	validation_1-mae:0.03319
# [7100]	validation_0-mae:0.03306	validation_1-mae:0.03319
# [7200]	validation_0-mae:0.03306	validation_1-mae:0.03319
# [7300]	validation_0-mae:0.03306	validation_1-mae:0.03319
# [7400]	validation_0-mae:0.03306	validation_1-mae:0.03319
# [7500]	validation_0-mae:0.03306	validation_1-mae:0.03319
# [7600]	validation_0-mae:0.03306	validation_1-mae:0.03319
# [7700]	validation_0-mae:0.03306	validation_1-mae:0.03319
# [7800]	validation_0-mae:0.03306	validation_1-mae:0.03319
# [7900]	validation_0-mae:0.03306	validation_1-mae:0.03319
# [8000]	validation_0-mae:0.03305	validation_1-mae:0.03319
# [8100]	validation_0-mae:0.03305	validation_1-mae:0.03319
# [8200]	validation_0-mae:0.03305	validation_1-mae:0.03318
# [8300]	validation_0-mae:0.03305	validation_1-mae:0.03318
# [8400]	validation_0-mae:0.03305	validation_1-mae:0.03318
# [8500]	validation_0-mae:0.03305	validation_1-mae:0.03318
# [8600]	validation_0-mae:0.03305	validation_1-mae:0.03318
# [8700]	validation_0-mae:0.03305	validation_1-mae:0.03318
# [8800]	validation_0-mae:0.03305	validation_1-mae:0.03318
# [8900]	validation_0-mae:0.03305	validation_1-mae:0.03318
# [9000]	validation_0-mae:0.03305	validation_1-mae:0.03318
# [9100]	validation_0-mae:0.03305	validation_1-mae:0.03318
# [9200]	validation_0-mae:0.03305	validation_1-mae:0.03318
# [9300]	validation_0-mae:0.03305	validation_1-mae:0.03318
# [9400]	validation_0-mae:0.03305	validation_1-mae:0.03318
# [9500]	validation_0-mae:0.03305	validation_1-mae:0.03318
# [9600]	validation_0-mae:0.03305	validation_1-mae:0.03318
# [9700]	validation_0-mae:0.03305	validation_1-mae:0.03318
# [9800]	validation_0-mae:0.03305	validation_1-mae:0.03318
# [9900]	validation_0-mae:0.03305	validation_1-mae:0.03318
# [9999]	validation_0-mae:0.03305	validation_1-mae:0.03318
# cv score is 0.0331769649074755
# OOF score is 0.03348882758957337
# ==================================================
# # z_0
# ==================================================
# ====== fold 0 ======
# [0]	validation_0-mae:0.02627	validation_1-mae:0.02676
# [100]	validation_0-mae:0.02619	validation_1-mae:0.02663
# [200]	validation_0-mae:0.02613	validation_1-mae:0.02653
# [300]	validation_0-mae:0.02609	validation_1-mae:0.02646
# [400]	validation_0-mae:0.02607	validation_1-mae:0.02644
# [500]	validation_0-mae:0.02606	validation_1-mae:0.02642
# [600]	validation_0-mae:0.02605	validation_1-mae:0.02642
# [700]	validation_0-mae:0.02605	validation_1-mae:0.02641
# [800]	validation_0-mae:0.02604	validation_1-mae:0.02641
# [900]	validation_0-mae:0.02604	validation_1-mae:0.02640
# [1000]	validation_0-mae:0.02604	validation_1-mae:0.02640
# [1100]	validation_0-mae:0.02604	validation_1-mae:0.02640
# [1200]	validation_0-mae:0.02604	validation_1-mae:0.02640
# [1300]	validation_0-mae:0.02604	validation_1-mae:0.02640
# [1400]	validation_0-mae:0.02604	validation_1-mae:0.02639
# [1500]	validation_0-mae:0.02603	validation_1-mae:0.02639
# [1600]	validation_0-mae:0.02603	validation_1-mae:0.02639
# [1700]	validation_0-mae:0.02603	validation_1-mae:0.02639
# [1800]	validation_0-mae:0.02603	validation_1-mae:0.02639
# [1900]	validation_0-mae:0.02603	validation_1-mae:0.02639
# [2000]	validation_0-mae:0.02603	validation_1-mae:0.02639
# [2100]	validation_0-mae:0.02603	validation_1-mae:0.02639
# [2200]	validation_0-mae:0.02603	validation_1-mae:0.02638
# [2287]	validation_0-mae:0.02603	validation_1-mae:0.02638
# cv score is 0.02638430073179195
# ====== fold 1 ======
# [0]	validation_0-mae:0.02630	validation_1-mae:0.02664
# [100]	validation_0-mae:0.02617	validation_1-mae:0.02658
# [200]	validation_0-mae:0.02608	validation_1-mae:0.02654
# [300]	validation_0-mae:0.02602	validation_1-mae:0.02652
# [400]	validation_0-mae:0.02597	validation_1-mae:0.02650
# [500]	validation_0-mae:0.02596	validation_1-mae:0.02649
# [600]	validation_0-mae:0.02595	validation_1-mae:0.02648
# [700]	validation_0-mae:0.02594	validation_1-mae:0.02648
# [800]	validation_0-mae:0.02594	validation_1-mae:0.02648
# [900]	validation_0-mae:0.02593	validation_1-mae:0.02648
# [1000]	validation_0-mae:0.02593	validation_1-mae:0.02648
# [1100]	validation_0-mae:0.02593	validation_1-mae:0.02648
# [1200]	validation_0-mae:0.02593	validation_1-mae:0.02647
# [1300]	validation_0-mae:0.02593	validation_1-mae:0.02647
# [1400]	validation_0-mae:0.02593	validation_1-mae:0.02647
# [1500]	validation_0-mae:0.02593	validation_1-mae:0.02647
# [1600]	validation_0-mae:0.02593	validation_1-mae:0.02647
# [1700]	validation_0-mae:0.02592	validation_1-mae:0.02647
# [1800]	validation_0-mae:0.02592	validation_1-mae:0.02647
# [1900]	validation_0-mae:0.02592	validation_1-mae:0.02647
# [2000]	validation_0-mae:0.02592	validation_1-mae:0.02647
# [2046]	validation_0-mae:0.02592	validation_1-mae:0.02647
# cv score is 0.026471679695892692
# ====== fold 2 ======
# [0]	validation_0-mae:0.02641	validation_1-mae:0.02620
# [100]	validation_0-mae:0.02632	validation_1-mae:0.02606
# [200]	validation_0-mae:0.02624	validation_1-mae:0.02597
# [300]	validation_0-mae:0.02619	validation_1-mae:0.02592
# [400]	validation_0-mae:0.02616	validation_1-mae:0.02588
# [500]	validation_0-mae:0.02615	validation_1-mae:0.02587
# [600]	validation_0-mae:0.02615	validation_1-mae:0.02587
# [700]	validation_0-mae:0.02614	validation_1-mae:0.02586
# [800]	validation_0-mae:0.02614	validation_1-mae:0.02586
# [900]	validation_0-mae:0.02614	validation_1-mae:0.02586
# [1000]	validation_0-mae:0.02613	validation_1-mae:0.02585
# [1100]	validation_0-mae:0.02613	validation_1-mae:0.02585
# [1200]	validation_0-mae:0.02613	validation_1-mae:0.02585
# [1213]	validation_0-mae:0.02613	validation_1-mae:0.02585
# cv score is 0.025848941861380318
# ====== fold 3 ======
# [0]	validation_0-mae:0.02635	validation_1-mae:0.02646
# [100]	validation_0-mae:0.02624	validation_1-mae:0.02639
# [200]	validation_0-mae:0.02615	validation_1-mae:0.02634
# [300]	validation_0-mae:0.02610	validation_1-mae:0.02630
# [400]	validation_0-mae:0.02606	validation_1-mae:0.02627
# [500]	validation_0-mae:0.02604	validation_1-mae:0.02626
# [600]	validation_0-mae:0.02603	validation_1-mae:0.02626
# [700]	validation_0-mae:0.02603	validation_1-mae:0.02626
# [800]	validation_0-mae:0.02603	validation_1-mae:0.02625
# [900]	validation_0-mae:0.02602	validation_1-mae:0.02625
# [1000]	validation_0-mae:0.02602	validation_1-mae:0.02625
# [1100]	validation_0-mae:0.02602	validation_1-mae:0.02625
# [1200]	validation_0-mae:0.02602	validation_1-mae:0.02625
# [1300]	validation_0-mae:0.02602	validation_1-mae:0.02625
# [1400]	validation_0-mae:0.02602	validation_1-mae:0.02624
# [1500]	validation_0-mae:0.02602	validation_1-mae:0.02624
# [1600]	validation_0-mae:0.02601	validation_1-mae:0.02624
# [1700]	validation_0-mae:0.02601	validation_1-mae:0.02624
# [1800]	validation_0-mae:0.02601	validation_1-mae:0.02624
# [1900]	validation_0-mae:0.02601	validation_1-mae:0.02624
# [2000]	validation_0-mae:0.02601	validation_1-mae:0.02624
# [2100]	validation_0-mae:0.02601	validation_1-mae:0.02624
# [2200]	validation_0-mae:0.02601	validation_1-mae:0.02624
# [2300]	validation_0-mae:0.02601	validation_1-mae:0.02624
# [2400]	validation_0-mae:0.02601	validation_1-mae:0.02624
# [2401]	validation_0-mae:0.02601	validation_1-mae:0.02624
# cv score is 0.026240494078986206
# ====== fold 4 ======
# [0]	validation_0-mae:0.02651	validation_1-mae:0.02580
# [100]	validation_0-mae:0.02640	validation_1-mae:0.02572
# [200]	validation_0-mae:0.02632	validation_1-mae:0.02566
# [300]	validation_0-mae:0.02626	validation_1-mae:0.02561
# [400]	validation_0-mae:0.02622	validation_1-mae:0.02559
# [500]	validation_0-mae:0.02620	validation_1-mae:0.02558
# [600]	validation_0-mae:0.02620	validation_1-mae:0.02557
# [700]	validation_0-mae:0.02619	validation_1-mae:0.02557
# [800]	validation_0-mae:0.02619	validation_1-mae:0.02557
# [900]	validation_0-mae:0.02619	validation_1-mae:0.02556
# [1000]	validation_0-mae:0.02618	validation_1-mae:0.02556
# [1100]	validation_0-mae:0.02618	validation_1-mae:0.02556
# [1200]	validation_0-mae:0.02618	validation_1-mae:0.02556
# [1300]	validation_0-mae:0.02618	validation_1-mae:0.02556
# [1400]	validation_0-mae:0.02618	validation_1-mae:0.02556
# [1500]	validation_0-mae:0.02618	validation_1-mae:0.02556
# [1600]	validation_0-mae:0.02618	validation_1-mae:0.02556
# [1700]	validation_0-mae:0.02618	validation_1-mae:0.02556
# [1800]	validation_0-mae:0.02618	validation_1-mae:0.02556
# [1870]	validation_0-mae:0.02618	validation_1-mae:0.02556
# cv score is 0.025556824060994646
# OOF score is 0.02609970085599477
# ==================================================
# # x_1
# ==================================================
# ====== fold 0 ======
# [0]	validation_0-mae:5.82266	validation_1-mae:5.87582
# [100]	validation_0-mae:4.32004	validation_1-mae:4.36096
# [200]	validation_0-mae:3.20555	validation_1-mae:3.23681
# [300]	validation_0-mae:2.37799	validation_1-mae:2.40135
# [400]	validation_0-mae:1.76632	validation_1-mae:1.78421
# [500]	validation_0-mae:1.31367	validation_1-mae:1.32751
# [600]	validation_0-mae:0.97824	validation_1-mae:0.98915
# [700]	validation_0-mae:0.73122	validation_1-mae:0.74000
# [800]	validation_0-mae:0.54996	validation_1-mae:0.55723
# [900]	validation_0-mae:0.41840	validation_1-mae:0.42516
# [1000]	validation_0-mae:0.32399	validation_1-mae:0.33102
# [1100]	validation_0-mae:0.25757	validation_1-mae:0.26499
# [1200]	validation_0-mae:0.21162	validation_1-mae:0.21952
# [1300]	validation_0-mae:0.18017	validation_1-mae:0.18882
# [1400]	validation_0-mae:0.15908	validation_1-mae:0.16848
# [1500]	validation_0-mae:0.14509	validation_1-mae:0.15514
# [1600]	validation_0-mae:0.13588	validation_1-mae:0.14661
# [1700]	validation_0-mae:0.12985	validation_1-mae:0.14117
# [1800]	validation_0-mae:0.12580	validation_1-mae:0.13770
# [1900]	validation_0-mae:0.12299	validation_1-mae:0.13552
# [2000]	validation_0-mae:0.12095	validation_1-mae:0.13416
# [2100]	validation_0-mae:0.11940	validation_1-mae:0.13329
# [2200]	validation_0-mae:0.11815	validation_1-mae:0.13274
# [2300]	validation_0-mae:0.11712	validation_1-mae:0.13236
# [2400]	validation_0-mae:0.11621	validation_1-mae:0.13211
# [2500]	validation_0-mae:0.11540	validation_1-mae:0.13193
# [2600]	validation_0-mae:0.11467	validation_1-mae:0.13179
# [2700]	validation_0-mae:0.11399	validation_1-mae:0.13170
# [2800]	validation_0-mae:0.11339	validation_1-mae:0.13164
# [2900]	validation_0-mae:0.11282	validation_1-mae:0.13159
# [3000]	validation_0-mae:0.11229	validation_1-mae:0.13156
# [3100]	validation_0-mae:0.11182	validation_1-mae:0.13155
# [3200]	validation_0-mae:0.11136	validation_1-mae:0.13152
# [3300]	validation_0-mae:0.11095	validation_1-mae:0.13151
# [3400]	validation_0-mae:0.11056	validation_1-mae:0.13151
# [3421]	validation_0-mae:0.11050	validation_1-mae:0.13151
# cv score is 0.1315047842478473
# ====== fold 1 ======
# [0]	validation_0-mae:5.85622	validation_1-mae:5.74809
# [100]	validation_0-mae:4.34523	validation_1-mae:4.26660
# [200]	validation_0-mae:3.22431	validation_1-mae:3.16754
# [300]	validation_0-mae:2.39190	validation_1-mae:2.35107
# [400]	validation_0-mae:1.77662	validation_1-mae:1.74816
# [500]	validation_0-mae:1.32113	validation_1-mae:1.30217
# [600]	validation_0-mae:0.98357	validation_1-mae:0.97215
# [700]	validation_0-mae:0.73486	validation_1-mae:0.72963
# [800]	validation_0-mae:0.55225	validation_1-mae:0.55185
# [900]	validation_0-mae:0.41983	validation_1-mae:0.42261
# [1000]	validation_0-mae:0.32496	validation_1-mae:0.33029
# [1100]	validation_0-mae:0.25815	validation_1-mae:0.26545
# [1200]	validation_0-mae:0.21189	validation_1-mae:0.22082
# [1300]	validation_0-mae:0.18038	validation_1-mae:0.19049
# [1400]	validation_0-mae:0.15923	validation_1-mae:0.17017
# [1500]	validation_0-mae:0.14523	validation_1-mae:0.15686
# [1600]	validation_0-mae:0.13607	validation_1-mae:0.14827
# [1700]	validation_0-mae:0.13008	validation_1-mae:0.14281
# [1800]	validation_0-mae:0.12603	validation_1-mae:0.13938
# [1900]	validation_0-mae:0.12317	validation_1-mae:0.13717
# [2000]	validation_0-mae:0.12106	validation_1-mae:0.13577
# [2100]	validation_0-mae:0.11949	validation_1-mae:0.13492
# [2200]	validation_0-mae:0.11821	validation_1-mae:0.13437
# [2300]	validation_0-mae:0.11716	validation_1-mae:0.13401
# [2400]	validation_0-mae:0.11625	validation_1-mae:0.13374
# [2500]	validation_0-mae:0.11545	validation_1-mae:0.13354
# [2600]	validation_0-mae:0.11473	validation_1-mae:0.13339
# [2700]	validation_0-mae:0.11405	validation_1-mae:0.13328
# [2800]	validation_0-mae:0.11343	validation_1-mae:0.13322
# [2900]	validation_0-mae:0.11285	validation_1-mae:0.13317
# [3000]	validation_0-mae:0.11234	validation_1-mae:0.13313
# [3100]	validation_0-mae:0.11187	validation_1-mae:0.13310
# [3200]	validation_0-mae:0.11141	validation_1-mae:0.13308
# [3300]	validation_0-mae:0.11101	validation_1-mae:0.13307
# [3400]	validation_0-mae:0.11064	validation_1-mae:0.13306
# [3500]	validation_0-mae:0.11032	validation_1-mae:0.13306
# [3600]	validation_0-mae:0.11000	validation_1-mae:0.13305
# [3698]	validation_0-mae:0.10975	validation_1-mae:0.13305
# cv score is 0.1330468091786608
# ====== fold 2 ======
# [0]	validation_0-mae:5.83304	validation_1-mae:5.83402
# [100]	validation_0-mae:4.32777	validation_1-mae:4.33212
# [200]	validation_0-mae:3.21121	validation_1-mae:3.21755
# [300]	validation_0-mae:2.38222	validation_1-mae:2.38968
# [400]	validation_0-mae:1.76949	validation_1-mae:1.77815
# [500]	validation_0-mae:1.31598	validation_1-mae:1.32557
# [600]	validation_0-mae:0.97994	validation_1-mae:0.98988
# [700]	validation_0-mae:0.73241	validation_1-mae:0.74254
# [800]	validation_0-mae:0.55079	validation_1-mae:0.56111
# [900]	validation_0-mae:0.41899	validation_1-mae:0.42934
# [1000]	validation_0-mae:0.32470	validation_1-mae:0.33459
# [1100]	validation_0-mae:0.25834	validation_1-mae:0.26774
# [1200]	validation_0-mae:0.21236	validation_1-mae:0.22133
# [1300]	validation_0-mae:0.18102	validation_1-mae:0.18978
# [1400]	validation_0-mae:0.15997	validation_1-mae:0.16875
# [1500]	validation_0-mae:0.14597	validation_1-mae:0.15496
# [1600]	validation_0-mae:0.13677	validation_1-mae:0.14606
# [1700]	validation_0-mae:0.13074	validation_1-mae:0.14041
# [1800]	validation_0-mae:0.12665	validation_1-mae:0.13687
# [1900]	validation_0-mae:0.12381	validation_1-mae:0.13461
# [2000]	validation_0-mae:0.12172	validation_1-mae:0.13320
# [2100]	validation_0-mae:0.12014	validation_1-mae:0.13229
# [2200]	validation_0-mae:0.11883	validation_1-mae:0.13166
# [2300]	validation_0-mae:0.11775	validation_1-mae:0.13122
# [2400]	validation_0-mae:0.11683	validation_1-mae:0.13089
# [2500]	validation_0-mae:0.11601	validation_1-mae:0.13064
# [2600]	validation_0-mae:0.11526	validation_1-mae:0.13048
# [2700]	validation_0-mae:0.11457	validation_1-mae:0.13035
# [2800]	validation_0-mae:0.11395	validation_1-mae:0.13025
# [2900]	validation_0-mae:0.11337	validation_1-mae:0.13018
# [3000]	validation_0-mae:0.11283	validation_1-mae:0.13012
# [3100]	validation_0-mae:0.11236	validation_1-mae:0.13008
# [3200]	validation_0-mae:0.11190	validation_1-mae:0.13006
# [3300]	validation_0-mae:0.11149	validation_1-mae:0.13003
# [3400]	validation_0-mae:0.11115	validation_1-mae:0.13001
# [3500]	validation_0-mae:0.11084	validation_1-mae:0.12999
# [3600]	validation_0-mae:0.11056	validation_1-mae:0.12999
# [3700]	validation_0-mae:0.11028	validation_1-mae:0.12998
# [3800]	validation_0-mae:0.11003	validation_1-mae:0.12996
# [3900]	validation_0-mae:0.10983	validation_1-mae:0.12995
# [4000]	validation_0-mae:0.10967	validation_1-mae:0.12994
# [4100]	validation_0-mae:0.10950	validation_1-mae:0.12993
# [4200]	validation_0-mae:0.10935	validation_1-mae:0.12993
# [4300]	validation_0-mae:0.10921	validation_1-mae:0.12993
# [4343]	validation_0-mae:0.10917	validation_1-mae:0.12993
# cv score is 0.12992301015998156
# ====== fold 3 ======
# [0]	validation_0-mae:5.84222	validation_1-mae:5.81328
# [100]	validation_0-mae:4.33482	validation_1-mae:4.31242
# [200]	validation_0-mae:3.21670	validation_1-mae:3.19966
# [300]	validation_0-mae:2.38632	validation_1-mae:2.37245
# [400]	validation_0-mae:1.77262	validation_1-mae:1.76148
# [500]	validation_0-mae:1.31833	validation_1-mae:1.30932
# ...
# [6800]	validation_0-mae:0.17137	validation_1-mae:0.66058
# [6900]	validation_0-mae:0.16930	validation_1-mae:0.66058
# [6955]	validation_0-mae:0.16816	validation_1-mae:0.66057
# cv score is 0.660566010316766
# OOF score is 0.658960514687957
# ==================================================
# # y_5
# ==================================================
# ====== fold 0 ======
# [0]	validation_0-mae:1.05577	validation_1-mae:1.06660
# [100]	validation_0-mae:0.83028	validation_1-mae:0.84184
# [200]	validation_0-mae:0.66842	validation_1-mae:0.68385
# [300]	validation_0-mae:0.55421	validation_1-mae:0.57602
# [400]	validation_0-mae:0.47389	validation_1-mae:0.50288
# [500]	validation_0-mae:0.41837	validation_1-mae:0.45589
# [600]	validation_0-mae:0.37988	validation_1-mae:0.42681
# [700]	validation_0-mae:0.35240	validation_1-mae:0.40880
# [800]	validation_0-mae:0.33217	validation_1-mae:0.39885
# [900]	validation_0-mae:0.31626	validation_1-mae:0.39311
# [1000]	validation_0-mae:0.30347	validation_1-mae:0.38975
# [1100]	validation_0-mae:0.29284	validation_1-mae:0.38755
# [1200]	validation_0-mae:0.28377	validation_1-mae:0.38611
# [1300]	validation_0-mae:0.27578	validation_1-mae:0.38517
# [1400]	validation_0-mae:0.26867	validation_1-mae:0.38458
# [1500]	validation_0-mae:0.26222	validation_1-mae:0.38419
# [1600]	validation_0-mae:0.25638	validation_1-mae:0.38395
# [1700]	validation_0-mae:0.25107	validation_1-mae:0.38367
# [1800]	validation_0-mae:0.24623	validation_1-mae:0.38346
# [1900]	validation_0-mae:0.24171	validation_1-mae:0.38327
# [2000]	validation_0-mae:0.23733	validation_1-mae:0.38315
# [2100]	validation_0-mae:0.23326	validation_1-mae:0.38312
# [2200]	validation_0-mae:0.22941	validation_1-mae:0.38307
# [2300]	validation_0-mae:0.22564	validation_1-mae:0.38297
# [2400]	validation_0-mae:0.22227	validation_1-mae:0.38294
# [2500]	validation_0-mae:0.21858	validation_1-mae:0.38293
# [2576]	validation_0-mae:0.21608	validation_1-mae:0.38294
# cv score is 0.3829166296304959
# ====== fold 1 ======
# [0]	validation_0-mae:1.05504	validation_1-mae:1.06955
# [100]	validation_0-mae:0.82987	validation_1-mae:0.84681
# [200]	validation_0-mae:0.66843	validation_1-mae:0.68868
# [300]	validation_0-mae:0.55488	validation_1-mae:0.57923
# [400]	validation_0-mae:0.47483	validation_1-mae:0.50489
# [500]	validation_0-mae:0.41949	validation_1-mae:0.45773
# [600]	validation_0-mae:0.38126	validation_1-mae:0.42876
# [700]	validation_0-mae:0.35380	validation_1-mae:0.41056
# [800]	validation_0-mae:0.33356	validation_1-mae:0.39914
# [900]	validation_0-mae:0.31782	validation_1-mae:0.39174
# [1000]	validation_0-mae:0.30525	validation_1-mae:0.38690
# [1100]	validation_0-mae:0.29477	validation_1-mae:0.38366
# [1200]	validation_0-mae:0.28589	validation_1-mae:0.38158
# [1300]	validation_0-mae:0.27784	validation_1-mae:0.38029
# [1400]	validation_0-mae:0.27058	validation_1-mae:0.37935
# [1500]	validation_0-mae:0.26415	validation_1-mae:0.37873
# [1600]	validation_0-mae:0.25821	validation_1-mae:0.37823
# [1700]	validation_0-mae:0.25269	validation_1-mae:0.37792
# [1800]	validation_0-mae:0.24774	validation_1-mae:0.37769
# [1900]	validation_0-mae:0.24306	validation_1-mae:0.37744
# [2000]	validation_0-mae:0.23880	validation_1-mae:0.37728
# [2100]	validation_0-mae:0.23458	validation_1-mae:0.37711
# [2200]	validation_0-mae:0.23074	validation_1-mae:0.37700
# [2300]	validation_0-mae:0.22707	validation_1-mae:0.37693
# [2400]	validation_0-mae:0.22345	validation_1-mae:0.37680
# [2500]	validation_0-mae:0.21999	validation_1-mae:0.37676
# [2600]	validation_0-mae:0.21652	validation_1-mae:0.37665
# [2700]	validation_0-mae:0.21320	validation_1-mae:0.37662
# [2800]	validation_0-mae:0.20983	validation_1-mae:0.37657
# [2900]	validation_0-mae:0.20665	validation_1-mae:0.37662
# [2913]	validation_0-mae:0.20623	validation_1-mae:0.37662
# cv score is 0.3765667474884874
# ====== fold 2 ======
# [0]	validation_0-mae:1.05776	validation_1-mae:1.05859
# [100]	validation_0-mae:0.83189	validation_1-mae:0.83480
# [200]	validation_0-mae:0.66984	validation_1-mae:0.67734
# [300]	validation_0-mae:0.55549	validation_1-mae:0.57038
# [400]	validation_0-mae:0.47481	validation_1-mae:0.49800
# [500]	validation_0-mae:0.41945	validation_1-mae:0.45186
# [600]	validation_0-mae:0.38142	validation_1-mae:0.42338
# [700]	validation_0-mae:0.35412	validation_1-mae:0.40608
# [800]	validation_0-mae:0.33392	validation_1-mae:0.39548
# [900]	validation_0-mae:0.31816	validation_1-mae:0.38911
# [1000]	validation_0-mae:0.30549	validation_1-mae:0.38521
# [1100]	validation_0-mae:0.29490	validation_1-mae:0.38290
# [1200]	validation_0-mae:0.28589	validation_1-mae:0.38143
# [1300]	validation_0-mae:0.27791	validation_1-mae:0.38058
# [1400]	validation_0-mae:0.27075	validation_1-mae:0.37987
# [1500]	validation_0-mae:0.26425	validation_1-mae:0.37937
# [1600]	validation_0-mae:0.25837	validation_1-mae:0.37897
# [1700]	validation_0-mae:0.25293	validation_1-mae:0.37866
# [1800]	validation_0-mae:0.24801	validation_1-mae:0.37844
# [1900]	validation_0-mae:0.24353	validation_1-mae:0.37824
# [2000]	validation_0-mae:0.23931	validation_1-mae:0.37808
# [2100]	validation_0-mae:0.23541	validation_1-mae:0.37794
# [2200]	validation_0-mae:0.23165	validation_1-mae:0.37783
# [2300]	validation_0-mae:0.22796	validation_1-mae:0.37774
# [2400]	validation_0-mae:0.22454	validation_1-mae:0.37765
# [2500]	validation_0-mae:0.22103	validation_1-mae:0.37755
# [2600]	validation_0-mae:0.21763	validation_1-mae:0.37746
# [2700]	validation_0-mae:0.21443	validation_1-mae:0.37740
# [2795]	validation_0-mae:0.21129	validation_1-mae:0.37739
# cv score is 0.3773894214143188
# ====== fold 3 ======
# [0]	validation_0-mae:1.06529	validation_1-mae:1.02898
# [100]	validation_0-mae:0.83725	validation_1-mae:0.80870
# [200]	validation_0-mae:0.67373	validation_1-mae:0.65362
# [300]	validation_0-mae:0.55860	validation_1-mae:0.54844
# [400]	validation_0-mae:0.47740	validation_1-mae:0.47935
# [500]	validation_0-mae:0.42149	validation_1-mae:0.43681
# [600]	validation_0-mae:0.38270	validation_1-mae:0.41228
# [700]	validation_0-mae:0.35494	validation_1-mae:0.39850
# [800]	validation_0-mae:0.33432	validation_1-mae:0.39086
# [900]	validation_0-mae:0.31838	validation_1-mae:0.38660
# [1000]	validation_0-mae:0.30570	validation_1-mae:0.38391
# [1100]	validation_0-mae:0.29518	validation_1-mae:0.38232
# [1200]	validation_0-mae:0.28610	validation_1-mae:0.38127
# [1300]	validation_0-mae:0.27820	validation_1-mae:0.38067
# [1400]	validation_0-mae:0.27113	validation_1-mae:0.38022
# [1500]	validation_0-mae:0.26469	validation_1-mae:0.37997
# [1600]	validation_0-mae:0.25888	validation_1-mae:0.37975
# [1700]	validation_0-mae:0.25359	validation_1-mae:0.37969
# [1800]	validation_0-mae:0.24855	validation_1-mae:0.37952
# [1900]	validation_0-mae:0.24411	validation_1-mae:0.37945
# [2000]	validation_0-mae:0.23991	validation_1-mae:0.37935
# [2100]	validation_0-mae:0.23592	validation_1-mae:0.37928
# [2200]	validation_0-mae:0.23214	validation_1-mae:0.37924
# [2300]	validation_0-mae:0.22861	validation_1-mae:0.37918
# [2400]	validation_0-mae:0.22491	validation_1-mae:0.37907
# [2500]	validation_0-mae:0.22136	validation_1-mae:0.37904
# [2600]	validation_0-mae:0.21784	validation_1-mae:0.37898
# [2700]	validation_0-mae:0.21443	validation_1-mae:0.37891
# [2800]	validation_0-mae:0.21106	validation_1-mae:0.37888
# [2900]	validation_0-mae:0.20791	validation_1-mae:0.37885
# [3000]	validation_0-mae:0.20458	validation_1-mae:0.37881
# [3100]	validation_0-mae:0.20140	validation_1-mae:0.37874
# [3200]	validation_0-mae:0.19816	validation_1-mae:0.37872
# [3300]	validation_0-mae:0.19520	validation_1-mae:0.37866
# [3400]	validation_0-mae:0.19238	validation_1-mae:0.37866
# [3453]	validation_0-mae:0.19090	validation_1-mae:0.37866
# cv score is 0.37863241220892296
# ====== fold 4 ======
# [0]	validation_0-mae:1.05603	validation_1-mae:1.06639
# [100]	validation_0-mae:0.83049	validation_1-mae:0.84553
# [200]	validation_0-mae:0.66877	validation_1-mae:0.68871
# [300]	validation_0-mae:0.55478	validation_1-mae:0.58106
# [400]	validation_0-mae:0.47427	validation_1-mae:0.50808
# [500]	validation_0-mae:0.41879	validation_1-mae:0.46067
# [600]	validation_0-mae:0.38060	validation_1-mae:0.43074
# [700]	validation_0-mae:0.35330	validation_1-mae:0.41227
# [800]	validation_0-mae:0.33298	validation_1-mae:0.40129
# [900]	validation_0-mae:0.31713	validation_1-mae:0.39428
# [1000]	validation_0-mae:0.30439	validation_1-mae:0.39011
# [1100]	validation_0-mae:0.29380	validation_1-mae:0.38746
# [1200]	validation_0-mae:0.28466	validation_1-mae:0.38574
# [1300]	validation_0-mae:0.27656	validation_1-mae:0.38471
# [1400]	validation_0-mae:0.26935	validation_1-mae:0.38387
# [1500]	validation_0-mae:0.26291	validation_1-mae:0.38324
# [1600]	validation_0-mae:0.25709	validation_1-mae:0.38270
# [1700]	validation_0-mae:0.25177	validation_1-mae:0.38229
# [1800]	validation_0-mae:0.24697	validation_1-mae:0.38199
# [1900]	validation_0-mae:0.24240	validation_1-mae:0.38166
# [2000]	validation_0-mae:0.23817	validation_1-mae:0.38149
# [2100]	validation_0-mae:0.23418	validation_1-mae:0.38123
# [2200]	validation_0-mae:0.23041	validation_1-mae:0.38102
# [2300]	validation_0-mae:0.22674	validation_1-mae:0.38088
# [2400]	validation_0-mae:0.22317	validation_1-mae:0.38078
# [2500]	validation_0-mae:0.21959	validation_1-mae:0.38070
# [2600]	validation_0-mae:0.21632	validation_1-mae:0.38059
# [2700]	validation_0-mae:0.21307	validation_1-mae:0.38054
# [2800]	validation_0-mae:0.20985	validation_1-mae:0.38050
# [2900]	validation_0-mae:0.20665	validation_1-mae:0.38045
# [3000]	validation_0-mae:0.20352	validation_1-mae:0.38040
# [3100]	validation_0-mae:0.20051	validation_1-mae:0.38036
# [3200]	validation_0-mae:0.19759	validation_1-mae:0.38032
# [3300]	validation_0-mae:0.19471	validation_1-mae:0.38031
# [3400]	validation_0-mae:0.19193	validation_1-mae:0.38026
# [3500]	validation_0-mae:0.18921	validation_1-mae:0.38025
# [3600]	validation_0-mae:0.18658	validation_1-mae:0.38025
# [3700]	validation_0-mae:0.18395	validation_1-mae:0.38024
# [3739]	validation_0-mae:0.18302	validation_1-mae:0.38024
# cv score is 0.38023190176428423
# OOF score is 0.37914982378158474
# ==================================================
# # z_5
# ==================================================
# ====== fold 0 ======
# [0]	validation_0-mae:0.18507	validation_1-mae:0.18434
# [100]	validation_0-mae:0.17915	validation_1-mae:0.17818
# [200]	validation_0-mae:0.17451	validation_1-mae:0.17416
# [300]	validation_0-mae:0.17076	validation_1-mae:0.17170
# [400]	validation_0-mae:0.16760	validation_1-mae:0.17003
# [500]	validation_0-mae:0.16482	validation_1-mae:0.16888
# [600]	validation_0-mae:0.16236	validation_1-mae:0.16820
# [700]	validation_0-mae:0.16001	validation_1-mae:0.16769
# [800]	validation_0-mae:0.15791	validation_1-mae:0.16738
# [900]	validation_0-mae:0.15597	validation_1-mae:0.16716
# [1000]	validation_0-mae:0.15412	validation_1-mae:0.16701
# [1100]	validation_0-mae:0.15236	validation_1-mae:0.16691
# [1200]	validation_0-mae:0.15070	validation_1-mae:0.16685
# [1300]	validation_0-mae:0.14912	validation_1-mae:0.16681
# [1400]	validation_0-mae:0.14758	validation_1-mae:0.16676
# [1500]	validation_0-mae:0.14615	validation_1-mae:0.16675
# [1600]	validation_0-mae:0.14477	validation_1-mae:0.16675
# [1642]	validation_0-mae:0.14420	validation_1-mae:0.16675
# cv score is 0.16674445949892558
# ====== fold 1 ======
# [0]	validation_0-mae:0.18479	validation_1-mae:0.18548
# [100]	validation_0-mae:0.17785	validation_1-mae:0.18311
# [200]	validation_0-mae:0.17258	validation_1-mae:0.18161
# [300]	validation_0-mae:0.16855	validation_1-mae:0.18062
# [400]	validation_0-mae:0.16518	validation_1-mae:0.17994
# [500]	validation_0-mae:0.16236	validation_1-mae:0.17950
# [600]	validation_0-mae:0.15991	validation_1-mae:0.17916
# [700]	validation_0-mae:0.15760	validation_1-mae:0.17896
# [800]	validation_0-mae:0.15557	validation_1-mae:0.17883
# [900]	validation_0-mae:0.15369	validation_1-mae:0.17871
# [1000]	validation_0-mae:0.15192	validation_1-mae:0.17862
# [1100]	validation_0-mae:0.15024	validation_1-mae:0.17858
# [1200]	validation_0-mae:0.14866	validation_1-mae:0.17849
# [1300]	validation_0-mae:0.14719	validation_1-mae:0.17842
# [1400]	validation_0-mae:0.14581	validation_1-mae:0.17837
# [1500]	validation_0-mae:0.14447	validation_1-mae:0.17834
# [1600]	validation_0-mae:0.14318	validation_1-mae:0.17832
# [1700]	validation_0-mae:0.14194	validation_1-mae:0.17829
# [1800]	validation_0-mae:0.14073	validation_1-mae:0.17827
# [1900]	validation_0-mae:0.13957	validation_1-mae:0.17825
# [2000]	validation_0-mae:0.13847	validation_1-mae:0.17825
# [2100]	validation_0-mae:0.13737	validation_1-mae:0.17825
# [2138]	validation_0-mae:0.13698	validation_1-mae:0.17825
# cv score is 0.17824440528090102
# ====== fold 2 ======
# [0]	validation_0-mae:0.18524	validation_1-mae:0.18368
# [100]	validation_0-mae:0.17918	validation_1-mae:0.17739
# [200]	validation_0-mae:0.17444	validation_1-mae:0.17350
# [300]	validation_0-mae:0.17065	validation_1-mae:0.17126
# [400]	validation_0-mae:0.16747	validation_1-mae:0.16986
# [500]	validation_0-mae:0.16469	validation_1-mae:0.16903
# [600]	validation_0-mae:0.16223	validation_1-mae:0.16856
# [700]	validation_0-mae:0.15997	validation_1-mae:0.16830
# [800]	validation_0-mae:0.15789	validation_1-mae:0.16822
# [900]	validation_0-mae:0.15597	validation_1-mae:0.16821
# [1000]	validation_0-mae:0.15411	validation_1-mae:0.16824
# [1027]	validation_0-mae:0.15361	validation_1-mae:0.16825
# cv score is 0.16819537967752432
# ====== fold 3 ======
# [0]	validation_0-mae:0.18437	validation_1-mae:0.18721
# [100]	validation_0-mae:0.17776	validation_1-mae:0.18449
# [200]	validation_0-mae:0.17273	validation_1-mae:0.18265
# [300]	validation_0-mae:0.16885	validation_1-mae:0.18136
# [400]	validation_0-mae:0.16562	validation_1-mae:0.18048
# [500]	validation_0-mae:0.16284	validation_1-mae:0.17992
# [600]	validation_0-mae:0.16043	validation_1-mae:0.17950
# [700]	validation_0-mae:0.15817	validation_1-mae:0.17913
# [800]	validation_0-mae:0.15616	validation_1-mae:0.17887
# [900]	validation_0-mae:0.15428	validation_1-mae:0.17867
# [1000]	validation_0-mae:0.15248	validation_1-mae:0.17854
# [1100]	validation_0-mae:0.15083	validation_1-mae:0.17841
# [1200]	validation_0-mae:0.14923	validation_1-mae:0.17833
# [1300]	validation_0-mae:0.14774	validation_1-mae:0.17825
# [1400]	validation_0-mae:0.14633	validation_1-mae:0.17821
# [1500]	validation_0-mae:0.14490	validation_1-mae:0.17819
# [1600]	validation_0-mae:0.14358	validation_1-mae:0.17816
# [1700]	validation_0-mae:0.14229	validation_1-mae:0.17816
# [1800]	validation_0-mae:0.14107	validation_1-mae:0.17813
# [1900]	validation_0-mae:0.13990	validation_1-mae:0.17812
# [2000]	validation_0-mae:0.13877	validation_1-mae:0.17811
# [2085]	validation_0-mae:0.13781	validation_1-mae:0.17811
# cv score is 0.1780975184545533
# ====== fold 4 ======
# [0]	validation_0-mae:0.18515	validation_1-mae:0.18406
# [100]	validation_0-mae:0.17850	validation_1-mae:0.18134
# [200]	validation_0-mae:0.17346	validation_1-mae:0.17949
# [300]	validation_0-mae:0.16950	validation_1-mae:0.17826
# [400]	validation_0-mae:0.16623	validation_1-mae:0.17735
# [500]	validation_0-mae:0.16349	validation_1-mae:0.17678
# [600]	validation_0-mae:0.16112	validation_1-mae:0.17638
# [700]	validation_0-mae:0.15889	validation_1-mae:0.17605
# [800]	validation_0-mae:0.15690	validation_1-mae:0.17581
# [900]	validation_0-mae:0.15502	validation_1-mae:0.17563
# [1000]	validation_0-mae:0.15323	validation_1-mae:0.17551
# [1100]	validation_0-mae:0.15160	validation_1-mae:0.17540
# [1200]	validation_0-mae:0.15002	validation_1-mae:0.17529
# [1300]	validation_0-mae:0.14853	validation_1-mae:0.17521
# [1400]	validation_0-mae:0.14706	validation_1-mae:0.17516
# [1500]	validation_0-mae:0.14568	validation_1-mae:0.17510
# [1600]	validation_0-mae:0.14439	validation_1-mae:0.17505
# [1700]	validation_0-mae:0.14306	validation_1-mae:0.17502
# [1800]	validation_0-mae:0.14181	validation_1-mae:0.17497
# [1900]	validation_0-mae:0.14063	validation_1-mae:0.17493
# [2000]	validation_0-mae:0.13947	validation_1-mae:0.17489
# [2100]	validation_0-mae:0.13831	validation_1-mae:0.17487
# [2200]	validation_0-mae:0.13725	validation_1-mae:0.17484
# [2300]	validation_0-mae:0.13625	validation_1-mae:0.17482
# [2400]	validation_0-mae:0.13524	validation_1-mae:0.17479
# [2500]	validation_0-mae:0.13426	validation_1-mae:0.17481
# [2533]	validation_0-mae:0.13397	validation_1-mae:0.17480
# cv score is 0.1747881915520785
# OOF score is 0.1732143803288437

# %%
test_pred = np.stack(test_pred, axis=1)
oof_pred = np.stack(oof_pred, axis=1)
np.save(os.path.join(config.output_dir, f"{config.exp}_test_pred.npy"), test_pred)
np.save(os.path.join(config.output_dir, f"{config.exp}_oof_pred.npy"), oof_pred)

import pickle
pickle.dump(models_dict, open(os.path.join(config.output_dir, f"{config.exp}_models_dict.pkl"), "wb"))

# %%
from joblib import Parallel, delayed

def get_trajectory(row):
    TARGET_COLUMNS = ['x_0', 'y_0', 'z_0', 'x_1', 'y_1', 'z_1', 'x_2', 'y_2', 'z_2', 'x_3', 'y_3', 'z_3', 'x_4', 'y_4', 'z_4', 'x_5', 'y_5', 'z_5']

    # データフレームのターゲット情報から可視化可能なtrajectoryに変換
    pivot_df = row[TARGET_COLUMNS].to_frame().reset_index()

    pivot_df.columns = ['coordinate', 'value']

    # 座標軸(x,y,z)と番号(0-5)を正規表現で抽出
    # 例：'x_0' -> axis='x', number='0'
    pivot_df[['axis', 'number']] = pivot_df['coordinate'].str.extract(r'([xyz])_(\d+)')

    # ピボットテーブルを作成：
    # - インデックス：番号(0-5)
    # - カラム：座標軸(x,y,z)
    # - 値：対応する座標値
    trajectory = pivot_df.pivot(index='number', columns='axis', values='value')

    # インデックスを数値型に変換
    trajectory.index = trajectory.index.astype(int)

    # インデックスでソートし、numpy配列に変換
    trajectory = trajectory.sort_index().values
    return trajectory

# Fetch trajectories in advance
train_trajectories = np.stack(Parallel(n_jobs=4)(delayed(get_trajectory)(row) for _, row in tqdm(train_df.iterrows(), total=len(train_df), desc="Fetching trajectories....")), axis=0)
train_trajectories = train_trajectories.astype("float")
# Out:
# Fetching trajectories....: 100%|██████████| 43371/43371 [00:35<00:00, 1206.12it/s]

# %%
oof_pred = np.load(os.path.join(config.output_dir, f"{config.exp}_oof_pred.npy"))
np.mean(np.abs(oof_pred - train_trajectories.reshape(len(train_df), -1)))
# Out:
# 0.19668316613392473

# %%
targets = ['x_0', 'y_0', 'z_0', 'x_1', 'y_1', 'z_1', 'x_2', 'y_2', 'z_2', 'x_3', 'y_3', 'z_3', 'x_4', 'y_4', 'z_4', 'x_5', 'y_5', 'z_5']

# oof_pred = np.load(os.path.join(config.output_dir, f"{config.exp}_oof_pred.npy"))
oof_pred = pd.DataFrame(oof_pred, columns=targets, index=train_df["ID"].values).reset_index(names="ID")
oof_pred.to_csv(os.path.join(config.output_dir, f"{config.exp}_oof_predictions.csv"), index=False)

# %%
targets = ['x_0', 'y_0', 'z_0', 'x_1', 'y_1', 'z_1', 'x_2', 'y_2', 'z_2', 'x_3', 'y_3', 'z_3', 'x_4', 'y_4', 'z_4', 'x_5', 'y_5', 'z_5']

test_preds = np.load(os.path.join(config.output_dir, f"{config.exp}_test_pred.npy"))
test_preds = pd.DataFrame(test_preds, columns=targets, index=test_df["ID"].values)

test_ids = pd.read_csv(os.path.join(config.input_dir, "test_features.csv"))["ID"].values
test_preds = test_preds.loc[test_ids].reset_index(drop=True)
display(test_preds.head())

test_preds.to_csv(os.path.join(config.output_dir, f"{config.exp}_submission.csv"), index=False)
# Out:
#         x_0       y_0       z_0       x_1  ...       z_4       x_5       y_5       z_5
# 0  1.485772 -0.011671  0.000472  3.050463  ...  0.034680  9.378392  0.149505  0.041442
# 1  0.954765  0.315889 -0.000582  1.860240  ... -0.013194  4.783461  4.802906 -0.007903
# 2  1.597676  0.008301 -0.000795  3.265235  ... -0.011488  9.268110  0.030441 -0.009579
# 3  0.866239  0.065679 -0.001379  1.652521  ... -0.018574  3.899815  1.958461 -0.017069
# 4  0.831110  0.002406 -0.000772  1.481703  ... -0.068266  1.767519  0.022380 -0.078957
#
# [5 rows x 18 columns]
